# %%
# Initialize Otter
import otter
grader = otter.Notebook("hw5.ipynb")

# %% [markdown]
# # CPSC 330 - Applied Machine Learning
#
# ## Homework 5: Putting it all together
# ### Associated lectures: All material till lecture 13
#
# **Due date: Monday, October 31st, 2022 at 11:59pm**

# %% [markdown]
# ## Table of contents
# 0. [Submission instructions](#si)
# 1. [Understanding the problem](#1)
# 2. [Data splitting](#2)
# 3. [EDA](#3)
# 4. (Challenging) [Feature engineering](#4)
# 5. [Preprocessing and transformations](#5)
# 6. [Baseline model](#6)
# 7. [Linear models](#7)
# 8. [Different models](#8)
# 9. (Challenging) [Feature selection](#9)
# 10. [Hyperparameter optimization](#10)
# 11. [Interpretation and feature importances](#11)
# 12. [Results on the test set](#12)
# 13. [Summary of the results](#13)
# 14. (Challenging) [Your takeaway from the course](#15)

# %% [markdown]
# ## Instructions
# <hr>
# rubric={points:6}
#
# Follow the [homework submission instructions](https://ubc-cs.github.io/cpsc330-2023W1/docs/homework_instructions.html).
#
# **You may work with a partner on this homework and submit your assignment as a group.** Below are some instructions on working as a group.
# - The maximum group size is 4.
# - Use group work as an opportunity to collaborate and learn new things from each other.
# - Be respectful to each other and make sure you understand all the concepts in the assignment well.
# - It's your responsibility to make sure that the assignment is submitted by one of the group members before the deadline.
# - You can find the instructions on how to do group submission on Gradescope [here](https://help.gradescope.com/article/m5qz2xsnjy-student-add-group-members).
#
#
# **When you are ready to submit your assignment do the following:**
#
# 1. Run all cells in your notebook to make sure there are no errors by doing `Kernel -> Restart Kernel and Clear All Outputs` and then `Run -> Run All Cells`.
# 2. Notebooks with cell execution numbers out of order or not starting from “1” will have marks deducted. Notebooks without the output displayed may not be graded at all (because we need to see the output in order to grade your work).
# 3. Upload the assignment using Gradescope's drag and drop tool. Check out this [Gradescope Student Guide](https://lthub.ubc.ca/guides/gradescope-student-guide/) if you need help with Gradescope submission.
# 4. Make sure that the plots and output are rendered properly in your submitted file.
# 5. If the .ipynb file is too big and doesn't render on Gradescope, also upload a pdf or html in addition to the .ipynb.

# %% [markdown]
# ## Imports

# %% [markdown]
# <!-- BEGIN QUESTION -->

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from IPython.display import HTML
import mglearn
from IPython.display import display

# Classifiers and regressors
from sklearn.dummy import DummyClassifier, DummyRegressor

# Preprocessing and pipeline
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline

# train test split and cross validation
from sklearn.model_selection import cross_val_score, cross_validate, train_test_split
from sklearn.neighbors import KNeighborsClassifier, KNeighborsRegressor
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import (
    MinMaxScaler,
    OneHotEncoder,
    OrdinalEncoder,
    StandardScaler,
)
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import Ridge 
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# <!-- END QUESTION -->
#
# ## Introduction <a name="in"></a>
#
# In this homework you will be working on an open-ended mini-project, where you will put all the different things you have learned so far together to solve an interesting problem.
#
# A few notes and tips when you work on this mini-project:
#
# #### Tips
# 1. This mini-project is open-ended, and while working on it, there might be some situations where you'll have to use your own judgment and make your own decisions (as you would be doing when you work as a data scientist). Make sure you explain your decisions whenever necessary.
# 2. **Do not include everything you ever tried in your submission** -- it's fine just to have your final code. That said, your code should be reproducible and well-documented. For example, if you chose your hyperparameters based on some hyperparameter optimization experiment, you should leave in the code for that experiment so that someone else could re-run it and obtain the same hyperparameters, rather than mysteriously just setting the hyperparameters to some (carefully chosen) values in your code.
# 3. If you realize that you are repeating a lot of code try to organize it in functions. Clear presentation of your code, experiments, and results is the key to be successful in this lab. You may use code from lecture notes or previous lab solutions with appropriate attributions.
#
# #### Assessment
# We plan to grade fairly and leniently. We don't have some secret target score that you need to achieve to get a good grade. **You'll be assessed on demonstration of mastery of course topics, clear presentation, and the quality of your analysis and results.** For example, if you just have a bunch of code and no text or figures, that's not good. If you do a bunch of sane things and get a lower accuracy than your friend, don't sweat it.
#
#
# #### A final note
# Finally, this style of this "project" question is different from other assignments. It'll be up to you to decide when you're "done" -- in fact, this is one of the hardest parts of real projects. But please don't spend WAY too much time on this... perhaps "a few hours" (15-20 hours???) is a good guideline for this project . Of course if you're having fun you're welcome to spend as much time as you want! But, if so, try not to do it out of perfectionism or getting the best possible grade. Do it because you're learning and enjoying it. Students from the past cohorts have found such kind of labs useful and fun and we hope you enjoy it as well.

# %% [markdown]
# <br><br>

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ## 1. Pick your problem and explain the prediction problem <a name="1"></a>
# <hr>
# rubric={points:3}
#
# In this assignment we'll be exploring a [dataset](https://www.kaggle.com/dgomonov/new-york-city-airbnb-open-data) of New York City Airbnb listings from 2019. As usual, you'll need to start by downloading the dataset. In this assignment we'll try to predict `reviews_per_month`, as a proxy for the popularity of the listing. Airbnb could use this sort of model to predict how popular future listings might be before they are posted, perhaps to help guide hosts create more appealing listings. In reality they might instead use something like vacancy rate or average rating as their target, but we do not have that available here.
#
# > Note there is an updated version of this dataset with more features available [here](http://insideairbnb.com/). The features were are using in `listings.csv.gz` for the New York city datasets. You will also see some other files like `reviews.csv.gz`. For your own interest you may want to explore the expanded dataset and try your analysis there. However, please submit your results on the dataset obtained from Kaggle.
#
# **Your tasks:**
#
# 1. Spend some time understanding the problem and what each feature means. You can find this information in the documentation on. You can find an explaination of the features [here](https://docs.google.com/spreadsheets/d/1iWCNJcSutYqpULSQHlNyGInUvHg2BoUGoNRIGa6Szc4/edit).  Write a few sentences on your initial thoughts on the problem and the dataset.
# 2. Download the dataset and read it as a pandas dataframe.

# %% [markdown]
# <div class="alert alert-warning">
#
# Solution_1
#
# </div>
#
# _Points:_ 3

# %% [markdown]
# _Type your answer here, replacing this text._

# %%
airbnb = pd.read_csv('AB_NYC_2019.csv')
airbnb.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room    149               1                  9  2018-10-19
# 1  Entire home/apt    225               1                 45  2019-05-21
# 2     Private room    150               3                  0         NaN
# 3  Entire home/apt     89               1                270  2019-07-05
# 4  Entire home/apt     80              10                  9  2018-11-19
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.21                               6               365
# 1               0.38                               2               355
# 2                NaN                               1               365
# 3               4.64                               1               194
# 4               0.10                               1                 0

# %% [markdown]
# <!-- END QUESTION -->
#
# <br><br>

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ## 2. Data splitting <a name="2"></a>
# <hr>
# rubric={points:2}
#
# **Your tasks:**
#
# 1. Split the data into train (70%) and test (30%) portions with `random_state=123`.
#
# > If your computer cannot handle training on 70% training data, make the test split bigger.

# %% [markdown]
# <div class="alert alert-warning">
#
# Solution_2
#
# </div>
#
# _Points:_ 2

# %%
airbnb['reviews_per_month'] = airbnb['reviews_per_month'].fillna(0) 
train, test = train_test_split(airbnb, test_size = 0.3, random_state=123)

# %% [markdown]
# <!-- END QUESTION -->
#
# <br><br>

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ## 3. EDA <a name="3"></a>
# <hr>
# rubric={points:10}
#
# **Your tasks:**
#
# 1. Perform exploratory data analysis on the train set.
# 2. Include at least two summary statistics and two visualizations that you find useful, and accompany each one with a sentence explaining it.
# 3. Summarize your initial observations about the data.
# 4. Pick appropriate metric/metrics for assessment.

# %% [markdown]
# <div class="alert alert-warning">
#
# Solution_3
#
# </div>
#
# _Points:_ 10

# %% [markdown]
# _Type your answer here, replacing this text._

# %%
plt.hist(airbnb['reviews_per_month'], bins=50)
# Out:
# (array([3.4127e+04, 6.4050e+03, 4.1720e+03, 2.2920e+03, 1.0310e+03,
#         4.3600e+02, 2.1400e+02, 9.6000e+01, 5.7000e+01, 2.5000e+01,
#         1.2000e+01, 1.4000e+01, 3.0000e+00, 5.0000e+00, 1.0000e+00,
#         1.0000e+00, 1.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00]),
#  array([ 0.  ,  1.17,  2.34,  3.51,  4.68,  5.85,  7.02,  8.19,  9.36,
#         10.53, 11.7 , 12.87, 14.04, 15.21, 16.38, 17.55, 18.72, 19.89,
#         21.06, 22.23, 23.4 , 24.57, 25.74, 26.91, 28.08, 29.25, 30.42,
#         31.59, 32.76, 33.93, 35.1 , 36.27, 37.44, 38.61, 39.78, 40.95,
#         42.12, 43.29, 44.46, 45.63, 46.8 , 47.97, 49.14, 50.31, 51.48,
#         52.65, 53.82, 54.99, 56.16, 57.33, 58.5 ]),
#  <BarContainer object of 50 artists>)

# %%
airbnb['reviews_per_month'].describe()
# Out:
# count    48895.000000
# mean         1.090910
# std          1.597283
# min          0.000000
# 25%          0.040000
# 50%          0.370000
# 75%          1.580000
# max         58.500000
# Name: reviews_per_month, dtype: float64

# %% [markdown]
# <!-- END QUESTION -->
#
# <br><br>

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ## (Challenging) 4. Feature engineering <a name="4"></a>
# <hr>
# rubric={points:1}
#
# **Your tasks:**
#
# 1. Carry out feature engineering. In other words, extract new features relevant for the problem and work with your new feature set in the following exercises. You may have to go back and forth between feature engineering and preprocessing.

# %% [markdown]
# <div class="alert alert-warning">
#
# Solution_4
#
# </div>
#
# _Points:_ 1

# %%
train['last_review'] = pd.to_datetime(airbnb['last_review'])
train['last_review_yr_month'] = train['last_review'].dt.strftime('%Y-%m')
test['last_review'] = pd.to_datetime(airbnb['last_review'])
test['last_review_yr_month'] = test['last_review'].dt.strftime('%Y-%m')

# %% [markdown]
# <!-- END QUESTION -->
#
# <br><br>

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ## 5. Preprocessing and transformations <a name="5"></a>
# <hr>
# rubric={points:10}
#
# **Your tasks:**
#
# 1. Identify any data cleaning that needs to be done and perform it.
# 2. Identify different feature types and the transformations you would apply on each feature type.
# 3. Define a column transformer, if necessary.
# 4. You have likely noticed the `number_of_reviews` feature will be higly informative for the target `reviews_per_month`. To make this assignment more interesting **drop** the `number_of_reviews` feature.

# %% [markdown]
# <div class="alert alert-warning">
#
# Solution_5
#
# </div>
#
# _Points:_ 10

# %% [markdown]
# _Type your answer here, replacing this text._

# %%
airbnb.describe(include='all')
# Out:
#                   id            name       host_id host_name  \
# count   4.889500e+04           48879  4.889500e+04     48874
# unique           NaN           47905           NaN     11452
# top              NaN  Hillside Hotel           NaN   Michael
# freq             NaN              18           NaN       417
# mean    1.901714e+07             NaN  6.762001e+07       NaN
# std     1.098311e+07             NaN  7.861097e+07       NaN
# min     2.539000e+03             NaN  2.438000e+03       NaN
# 25%     9.471945e+06             NaN  7.822033e+06       NaN
# 50%     1.967728e+07             NaN  3.079382e+07       NaN
# 75%     2.915218e+07             NaN  1.074344e+08       NaN
# max     3.648724e+07             NaN  2.743213e+08       NaN
#
#        neighbourhood_group neighbourhood      latitude     longitude  \
# count                48895         48895  48895.000000  48895.000000
# unique                   5           221           NaN           NaN
# top              Manhattan  Williamsburg           NaN           NaN
# freq                 21661          3920           NaN           NaN
# mean                   NaN           NaN     40.728949    -73.952170
# std                    NaN           NaN      0.054530      0.046157
# min                    NaN           NaN     40.499790    -74.244420
# 25%                    NaN           NaN     40.690100    -73.983070
# 50%                    NaN           NaN     40.723070    -73.955680
# 75%                    NaN           NaN     40.763115    -73.936275
# max                    NaN           NaN     40.913060    -73.712990
#
#               room_type         price  minimum_nights  number_of_reviews  \
# count             48895  48895.000000    48895.000000       48895.000000
# unique                3           NaN             NaN                NaN
# top     Entire home/apt           NaN             NaN                NaN
# freq              25409           NaN             NaN                NaN
# mean                NaN    152.720687        7.029962          23.274466
# std                 NaN    240.154170       20.510550          44.550582
# min                 NaN      0.000000        1.000000           0.000000
# 25%                 NaN     69.000000        1.000000           1.000000
# 50%                 NaN    106.000000        3.000000           5.000000
# 75%                 NaN    175.000000        5.000000          24.000000
# max                 NaN  10000.000000     1250.000000         629.000000
#
#        last_review  reviews_per_month  calculated_host_listings_count  \
# count        38843       48895.000000                    48895.000000
# unique        1764                NaN                             NaN
# top     2019-06-23                NaN                             NaN
# freq          1413                NaN                             NaN
# mean           NaN           1.090910                        7.143982
# std            NaN           1.597283                       32.952519
# min            NaN           0.000000                        1.000000
# 25%            NaN           0.040000                        1.000000
# 50%            NaN           0.370000                        1.000000
# 75%            NaN           1.580000                        2.000000
# max            NaN          58.500000                      327.000000
#
#         availability_365
# count       48895.000000
# unique               NaN
# top                  NaN
# freq                 NaN
# mean          112.781327
# std           131.622289
# min             0.000000
# 25%             0.000000
# 50%            45.000000
# 75%           227.000000
# max           365.000000

# %%
train.value_counts(['last_review_yr_month'])
# Out:
# last_review_yr_month
# 2019-06                 8865
# 2019-07                 3273
# 2019-05                 2592
# 2019-04                 1015
# 2019-01                 1003
#                         ...
# 2011-04                    1
# 2012-07                    1
# 2011-05                    1
# 2014-02                    1
# 2011-03                    1
# Name: count, Length: 90, dtype: int64

# %%
na_counts = airbnb.isna().sum()
na_counts
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                     0
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
categorical_features = ['neighbourhood_group']
ordinal_features = ['room_type']
text_features = ['name']
numeric_features = ['latitude', 'longitude', 'price', 'minimum_nights', 'calculated_host_listings_count', 'availability_365']
drop_features = ['number_of_reviews', 'id', 'host_id', 'host_name', 'last_review', 'name', 'last_review_yr_month', 'neighbourhood']

# %%
room_levels = ['Private room', 'Shared room','Entire home/apt']

# %%
from sklearn.compose import make_column_transformer
from sklearn.feature_extraction.text import CountVectorizer

ordinal_transformer = make_pipeline(OrdinalEncoder(categories=[room_levels], dtype=int))
numeric_transformer = make_pipeline(StandardScaler())
categorical_transformer = make_pipeline(OneHotEncoder(handle_unknown='ignore'))
text_transformer = make_pipeline(CountVectorizer(stop_words='english', max_features=1000))


preprocessor = make_column_transformer(
    (numeric_transformer, numeric_features), 
    (ordinal_transformer, ordinal_features), 
    (categorical_transformer, categorical_features), 
    # (text_transformer, text_features),
    ('drop', drop_features)
)

# %%
X_train = train.drop(columns= ['reviews_per_month'])
x_test = test.drop(columns= ['reviews_per_month'])
y_train = train['reviews_per_month']
y_test = test['reviews_per_month']

# %% [markdown]
# <!-- END QUESTION -->
#
# <br><br>

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ## 6. Baseline model <a name="6"></a>
# <hr>
# rubric={points:2}
#
# **Your tasks:**
# 1. Try `scikit-learn`'s baseline model and report results.

# %% [markdown]
# <div class="alert alert-warning">
#
# Solution_6
#
# </div>
#
# _Points:_ 2

# %%
from sklearn.dummy import DummyClassifier

dummy = DummyRegressor(strategy='median')
dummy_pip = make_pipeline(preprocessor, dummy)

score = cross_validate(dummy, X_train, y_train, return_train_score=True)
score
# Out:
# {'fit_time': array([0.01019788, 0.00757575, 0.00699496, 0.00548196, 0.00467086]),
#  'score_time': array([0.00209522, 0.00179291, 0.00094485, 0.00113797, 0.00086713]),
#  'test_score': array([-0.20123875, -0.19812534, -0.1806408 , -0.21424867, -0.19230697]),
#  'train_score': array([-0.19833383, -0.19226051, -0.20414967, -0.19535755, -0.19372557])}

# %% [markdown]
# <!-- END QUESTION -->

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ## 7. Linear models <a name="7"></a>
# <hr>
# rubric={points:10}
#
# **Your tasks:**
#
# 1. Try a linear model as a first real attempt.
# 2. Carry out hyperparameter tuning to explore different values for the complexity hyperparameter.
# 3. Report cross-validation scores along with standard deviation.
# 4. Summarize your results.

# %% [markdown]
# <div class="alert alert-warning">
#
# Solution_7
#
# </div>
#
# _Points:_ 10

# %% [markdown]
# _Type your answer here, replacing this text._

# %%
linear_pip = make_pipeline(preprocessor, Ridge())

linear_scores = cross_validate(linear_pip, X_train, y_train, return_train_score=True)
linear_scores
# Out:
# {'fit_time': array([0.04865503, 0.06557894, 0.04087615, 0.0487771 , 0.04129887]),
#  'score_time': array([0.02199721, 0.0153451 , 0.00998998, 0.01307583, 0.00934124]),
#  'test_score': array([0.079162  , 0.06270343, 0.06547218, 0.07849038, 0.06527731]),
#  'train_score': array([0.06958213, 0.07372431, 0.07330505, 0.06992951, 0.07277853])}

# %%
# code adapted from lecture 7
scores_dict = {
    "alpha": 10.0 ** np.arange(-3, 6, 1),
    "mean_train_scores": list(),
    "mean_cv_scores": list(),
}

for alpha in scores_dict["alpha"]:
    pipe_ridge = make_pipeline(preprocessor, Ridge(alpha=alpha))
    scores = cross_validate(pipe_ridge, X_train, y_train, return_train_score=True)
    scores_dict["mean_train_scores"].append(scores["train_score"].mean())
    scores_dict["mean_cv_scores"].append(scores["test_score"].mean())

results_df = pd.DataFrame(scores_dict)
results_df
# Out:
#         alpha  mean_train_scores  mean_cv_scores
# 0       0.001           0.071864        0.070221
# 1       0.010           0.071864        0.070221
# 2       0.100           0.071864        0.070221
# 3       1.000           0.071864        0.070221
# 4      10.000           0.071862        0.070222
# 5     100.000           0.071760        0.070147
# 6    1000.000           0.070937        0.069495
# 7   10000.000           0.063936        0.063209
# 8  100000.000           0.026204        0.026138

# %% [markdown]
# <!-- END QUESTION -->
#
# <br><br>

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ## 8. Different models <a name="8"></a>
# <hr>
# rubric={points:12}
#
# **Your tasks:**
# 1. Try at least 3 other models aside from a linear model. One of these models should be a tree-based ensemble model.
# 2. Summarize your results in terms of overfitting/underfitting and fit and score times. Can you beat a linear model?

# %% [markdown]
# <div class="alert alert-warning">
#
# Solution_8
#
# </div>
#
# _Points:_ 12

# %% [markdown]
# _Type your answer here, replacing this text._

# %%
dtree_pip = make_pipeline(preprocessor, DecisionTreeRegressor(random_state=123))
cross_validate(dtree_pip, X_train, y_train, return_train_score=True)

# %%
random_pip = make_pipeline(preprocessor, RandomForestRegressor(random_state=123))
random_score = cross_validate(random_pip, X_train, y_train, return_train_score=True)
random_score
# Out:
# {'fit_time': array([16.77576017, 16.16061211, 18.61270094, 16.71971512, 18.59391618]),
#  'score_time': array([0.38358283, 0.27884603, 0.21703219, 0.25835085, 0.23963594]),
#  'test_score': array([0.3897552 , 0.34679058, 0.32338627, 0.3898613 , 0.3707203 ]),
#  'train_score': array([0.91189677, 0.91133312, 0.91215562, 0.90861011, 0.90937717])}

# %%
from catboost import CatBoostRegressor
xgb_pip = make_pipeline(preprocessor, CatBoostRegressor(random_state=123))
xgb_score = cross_validate(xgb_pip, X_train, y_train, return_train_score=True)
xgb_score
# Out:
# Learning rate set to 0.069071
# 0:	learn: 1.5877626	total: 8.2ms	remaining: 8.19s
# 1:	learn: 1.5625880	total: 20.4ms	remaining: 10.2s
# 2:	learn: 1.5410401	total: 28.5ms	remaining: 9.47s
# 3:	learn: 1.5213963	total: 36.3ms	remaining: 9.04s
# 4:	learn: 1.5035010	total: 43.8ms	remaining: 8.71s
# 5:	learn: 1.4880129	total: 50.8ms	remaining: 8.42s
# 6:	learn: 1.4737997	total: 60.2ms	remaining: 8.54s
# 7:	learn: 1.4614244	total: 68.4ms	remaining: 8.48s
# 8:	learn: 1.4511292	total: 83.6ms	remaining: 9.21s
# 9:	learn: 1.4412608	total: 89.8ms	remaining: 8.89s
# 10:	learn: 1.4324746	total: 96.4ms	remaining: 8.67s
# 11:	learn: 1.4246929	total: 102ms	remaining: 8.39s
# 12:	learn: 1.4172089	total: 105ms	remaining: 8.01s
# 13:	learn: 1.4109895	total: 109ms	remaining: 7.71s
# 14:	learn: 1.4048670	total: 217ms	remaining: 14.3s
# 15:	learn: 1.3994778	total: 223ms	remaining: 13.7s
# 16:	learn: 1.3947176	total: 270ms	remaining: 15.6s
# 17:	learn: 1.3907776	total: 276ms	remaining: 15s
# 18:	learn: 1.3864700	total: 282ms	remaining: 14.6s
# 19:	learn: 1.3821710	total: 289ms	remaining: 14.1s
# 20:	learn: 1.3786852	total: 294ms	remaining: 13.7s
# 21:	learn: 1.3753483	total: 299ms	remaining: 13.3s
# 22:	learn: 1.3728594	total: 308ms	remaining: 13.1s
# 23:	learn: 1.3708051	total: 317ms	remaining: 12.9s
# 24:	learn: 1.3677109	total: 324ms	remaining: 12.6s
# 25:	learn: 1.3653880	total: 329ms	remaining: 12.3s
# 26:	learn: 1.3634180	total: 335ms	remaining: 12.1s
# 27:	learn: 1.3611456	total: 376ms	remaining: 13s
# 28:	learn: 1.3581109	total: 393ms	remaining: 13.2s
# 29:	learn: 1.3561890	total: 402ms	remaining: 13s
# 30:	learn: 1.3545989	total: 412ms	remaining: 12.9s
# 31:	learn: 1.3532488	total: 419ms	remaining: 12.7s
# 32:	learn: 1.3515622	total: 424ms	remaining: 12.4s
# 33:	learn: 1.3503981	total: 429ms	remaining: 12.2s
# 34:	learn: 1.3493804	total: 434ms	remaining: 12s
# 35:	learn: 1.3478612	total: 440ms	remaining: 11.8s
# 36:	learn: 1.3456121	total: 446ms	remaining: 11.6s
# 37:	learn: 1.3441456	total: 456ms	remaining: 11.5s
# 38:	learn: 1.3429514	total: 460ms	remaining: 11.3s
# 39:	learn: 1.3415561	total: 463ms	remaining: 11.1s
# 40:	learn: 1.3402463	total: 466ms	remaining: 10.9s
# 41:	learn: 1.3396146	total: 470ms	remaining: 10.7s
# 42:	learn: 1.3378078	total: 475ms	remaining: 10.6s
# 43:	learn: 1.3359277	total: 478ms	remaining: 10.4s
# 44:	learn: 1.3349476	total: 481ms	remaining: 10.2s
# 45:	learn: 1.3339345	total: 484ms	remaining: 10s
# 46:	learn: 1.3322517	total: 490ms	remaining: 9.94s
# 47:	learn: 1.3310606	total: 495ms	remaining: 9.81s
# 48:	learn: 1.3299989	total: 499ms	remaining: 9.69s
# 49:	learn: 1.3292358	total: 502ms	remaining: 9.54s
# 50:	learn: 1.3282996	total: 505ms	remaining: 9.39s
# 51:	learn: 1.3272060	total: 508ms	remaining: 9.26s
# 52:	learn: 1.3262906	total: 510ms	remaining: 9.12s
# 53:	learn: 1.3251155	total: 514ms	remaining: 9s
# 54:	learn: 1.3242103	total: 517ms	remaining: 8.88s
# 55:	learn: 1.3229399	total: 520ms	remaining: 8.76s
# 56:	learn: 1.3221611	total: 523ms	remaining: 8.64s
# 57:	learn: 1.3216214	total: 525ms	remaining: 8.53s
# 58:	learn: 1.3208421	total: 528ms	remaining: 8.42s
# 59:	learn: 1.3202354	total: 531ms	remaining: 8.32s
# 60:	learn: 1.3193805	total: 534ms	remaining: 8.22s
# 61:	learn: 1.3186387	total: 537ms	remaining: 8.12s
# 62:	learn: 1.3179726	total: 540ms	remaining: 8.03s
# 63:	learn: 1.3174915	total: 543ms	remaining: 7.94s
# 64:	learn: 1.3169792	total: 547ms	remaining: 7.87s
# 65:	learn: 1.3155848	total: 550ms	remaining: 7.79s
# 66:	learn: 1.3150803	total: 556ms	remaining: 7.74s
# 67:	learn: 1.3140616	total: 559ms	remaining: 7.66s
# 68:	learn: 1.3133275	total: 562ms	remaining: 7.59s
# 69:	learn: 1.3128794	total: 567ms	remaining: 7.53s
# 70:	learn: 1.3122553	total: 572ms	remaining: 7.49s
# 71:	learn: 1.3115627	total: 579ms	remaining: 7.46s
# 72:	learn: 1.3100095	total: 583ms	remaining: 7.4s
# 73:	learn: 1.3093606	total: 587ms	remaining: 7.35s
# 74:	learn: 1.3087658	total: 592ms	remaining: 7.31s
# 75:	learn: 1.3076845	total: 596ms	remaining: 7.25s
# 76:	learn: 1.3072153	total: 602ms	remaining: 7.21s
# 77:	learn: 1.3061886	total: 607ms	remaining: 7.17s
# 78:	learn: 1.3051993	total: 613ms	remaining: 7.14s
# 79:	learn: 1.3045438	total: 615ms	remaining: 7.08s
# 80:	learn: 1.3040209	total: 619ms	remaining: 7.02s
# 81:	learn: 1.3027340	total: 621ms	remaining: 6.95s
# 82:	learn: 1.3017524	total: 625ms	remaining: 6.91s
# 83:	learn: 1.3013046	total: 629ms	remaining: 6.86s
# 84:	learn: 1.3003321	total: 632ms	remaining: 6.8s
# 85:	learn: 1.2998618	total: 637ms	remaining: 6.77s
# 86:	learn: 1.2992235	total: 644ms	remaining: 6.75s
# 87:	learn: 1.2987143	total: 647ms	remaining: 6.71s
# 88:	learn: 1.2979886	total: 652ms	remaining: 6.67s
# 89:	learn: 1.2970775	total: 655ms	remaining: 6.62s
# 90:	learn: 1.2967201	total: 661ms	remaining: 6.6s
# 91:	learn: 1.2964078	total: 665ms	remaining: 6.56s
# 92:	learn: 1.2957645	total: 668ms	remaining: 6.51s
# 93:	learn: 1.2950733	total: 673ms	remaining: 6.48s
# 94:	learn: 1.2947413	total: 676ms	remaining: 6.44s
# 95:	learn: 1.2942657	total: 679ms	remaining: 6.39s
# 96:	learn: 1.2919804	total: 684ms	remaining: 6.37s
# 97:	learn: 1.2916051	total: 691ms	remaining: 6.36s
# 98:	learn: 1.2906340	total: 698ms	remaining: 6.35s
# 99:	learn: 1.2904509	total: 703ms	remaining: 6.32s
# 100:	learn: 1.2900893	total: 706ms	remaining: 6.28s
# 101:	learn: 1.2898365	total: 709ms	remaining: 6.24s
# 102:	learn: 1.2895279	total: 713ms	remaining: 6.21s
# 103:	learn: 1.2893009	total: 716ms	remaining: 6.17s
# 104:	learn: 1.2889552	total: 719ms	remaining: 6.13s
# 105:	learn: 1.2877930	total: 723ms	remaining: 6.1s
# 106:	learn: 1.2874592	total: 726ms	remaining: 6.06s
# 107:	learn: 1.2869618	total: 730ms	remaining: 6.03s
# 108:	learn: 1.2860685	total: 733ms	remaining: 5.99s
# 109:	learn: 1.2856756	total: 738ms	remaining: 5.97s
# 110:	learn: 1.2851646	total: 741ms	remaining: 5.93s
# 111:	learn: 1.2846371	total: 744ms	remaining: 5.9s
# 112:	learn: 1.2843265	total: 747ms	remaining: 5.86s
# 113:	learn: 1.2837981	total: 749ms	remaining: 5.82s
# 114:	learn: 1.2835003	total: 752ms	remaining: 5.79s
# 115:	learn: 1.2831683	total: 755ms	remaining: 5.75s
# 116:	learn: 1.2820831	total: 759ms	remaining: 5.73s
# 117:	learn: 1.2814071	total: 762ms	remaining: 5.7s
# 118:	learn: 1.2811082	total: 764ms	remaining: 5.66s
# 119:	learn: 1.2795799	total: 767ms	remaining: 5.63s
# 120:	learn: 1.2790093	total: 770ms	remaining: 5.59s
# 121:	learn: 1.2780411	total: 775ms	remaining: 5.58s
# 122:	learn: 1.2778265	total: 778ms	remaining: 5.55s
# 123:	learn: 1.2770361	total: 780ms	remaining: 5.51s
# 124:	learn: 1.2762976	total: 784ms	remaining: 5.49s
# 125:	learn: 1.2759100	total: 789ms	remaining: 5.47s
# 126:	learn: 1.2755529	total: 792ms	remaining: 5.45s
# 127:	learn: 1.2751061	total: 795ms	remaining: 5.42s
# 128:	learn: 1.2748795	total: 798ms	remaining: 5.39s
# 129:	learn: 1.2746500	total: 803ms	remaining: 5.37s
# 130:	learn: 1.2743323	total: 806ms	remaining: 5.35s
# 131:	learn: 1.2736439	total: 809ms	remaining: 5.32s
# 132:	learn: 1.2731366	total: 811ms	remaining: 5.29s
# 133:	learn: 1.2728560	total: 815ms	remaining: 5.27s
# 134:	learn: 1.2723267	total: 819ms	remaining: 5.25s
# 135:	learn: 1.2717187	total: 823ms	remaining: 5.23s
# 136:	learn: 1.2702906	total: 827ms	remaining: 5.21s
# 137:	learn: 1.2699429	total: 831ms	remaining: 5.19s
# 138:	learn: 1.2690569	total: 836ms	remaining: 5.18s
# 139:	learn: 1.2688779	total: 839ms	remaining: 5.16s
# 140:	learn: 1.2675821	total: 841ms	remaining: 5.13s
# 141:	learn: 1.2672852	total: 845ms	remaining: 5.1s
# 142:	learn: 1.2670203	total: 847ms	remaining: 5.08s
# 143:	learn: 1.2665999	total: 850ms	remaining: 5.05s
# 144:	learn: 1.2662759	total: 853ms	remaining: 5.03s
# 145:	learn: 1.2658946	total: 855ms	remaining: 5s
# 146:	learn: 1.2655346	total: 858ms	remaining: 4.98s
# 147:	learn: 1.2653613	total: 861ms	remaining: 4.96s
# 148:	learn: 1.2645129	total: 864ms	remaining: 4.94s
# 149:	learn: 1.2642874	total: 868ms	remaining: 4.92s
# 150:	learn: 1.2637246	total: 871ms	remaining: 4.9s
# 151:	learn: 1.2633740	total: 874ms	remaining: 4.88s
# 152:	learn: 1.2628856	total: 877ms	remaining: 4.85s
# 153:	learn: 1.2624274	total: 879ms	remaining: 4.83s
# 154:	learn: 1.2621134	total: 882ms	remaining: 4.81s
# 155:	learn: 1.2619328	total: 887ms	remaining: 4.8s
# 156:	learn: 1.2616464	total: 890ms	remaining: 4.78s
# 157:	learn: 1.2611149	total: 892ms	remaining: 4.75s
# 158:	learn: 1.2606624	total: 895ms	remaining: 4.73s
# 159:	learn: 1.2599211	total: 897ms	remaining: 4.71s
# 160:	learn: 1.2596559	total: 901ms	remaining: 4.69s
# 161:	learn: 1.2590520	total: 904ms	remaining: 4.67s
# 162:	learn: 1.2575341	total: 906ms	remaining: 4.65s
# 163:	learn: 1.2573550	total: 908ms	remaining: 4.63s
# 164:	learn: 1.2569331	total: 911ms	remaining: 4.61s
# 165:	learn: 1.2565482	total: 914ms	remaining: 4.59s
# 166:	learn: 1.2559803	total: 917ms	remaining: 4.58s
# 167:	learn: 1.2552611	total: 920ms	remaining: 4.56s
# 168:	learn: 1.2549003	total: 923ms	remaining: 4.54s
# 169:	learn: 1.2542596	total: 927ms	remaining: 4.53s
# 170:	learn: 1.2537977	total: 931ms	remaining: 4.51s
# 171:	learn: 1.2532200	total: 934ms	remaining: 4.5s
# 172:	learn: 1.2528078	total: 936ms	remaining: 4.48s
# 173:	learn: 1.2520407	total: 939ms	remaining: 4.46s
# 174:	learn: 1.2518159	total: 942ms	remaining: 4.44s
# 175:	learn: 1.2514037	total: 946ms	remaining: 4.43s
# 176:	learn: 1.2501290	total: 949ms	remaining: 4.41s
# 177:	learn: 1.2499289	total: 952ms	remaining: 4.39s
# 178:	learn: 1.2494368	total: 954ms	remaining: 4.38s
# 179:	learn: 1.2490437	total: 958ms	remaining: 4.36s
# 180:	learn: 1.2487467	total: 961ms	remaining: 4.35s
# 181:	learn: 1.2485754	total: 964ms	remaining: 4.33s
# 182:	learn: 1.2483601	total: 966ms	remaining: 4.31s
# 183:	learn: 1.2479902	total: 969ms	remaining: 4.29s
# 184:	learn: 1.2476211	total: 973ms	remaining: 4.28s
# 185:	learn: 1.2473049	total: 976ms	remaining: 4.27s
# 186:	learn: 1.2468459	total: 979ms	remaining: 4.25s
# 187:	learn: 1.2466825	total: 981ms	remaining: 4.24s
# 188:	learn: 1.2461720	total: 984ms	remaining: 4.22s
# 189:	learn: 1.2458422	total: 986ms	remaining: 4.2s
# 190:	learn: 1.2455329	total: 989ms	remaining: 4.19s
# 191:	learn: 1.2438279	total: 992ms	remaining: 4.18s
# 192:	learn: 1.2435682	total: 996ms	remaining: 4.16s
# 193:	learn: 1.2430816	total: 998ms	remaining: 4.15s
# 194:	learn: 1.2425107	total: 1s	remaining: 4.13s
# 195:	learn: 1.2422144	total: 1s	remaining: 4.11s
# 196:	learn: 1.2419416	total: 1s	remaining: 4.1s
# 197:	learn: 1.2416750	total: 1.01s	remaining: 4.08s
# 198:	learn: 1.2411394	total: 1.01s	remaining: 4.07s
# 199:	learn: 1.2408178	total: 1.02s	remaining: 4.06s
# 200:	learn: 1.2404508	total: 1.02s	remaining: 4.05s
# 201:	learn: 1.2400474	total: 1.02s	remaining: 4.05s
# 202:	learn: 1.2395800	total: 1.03s	remaining: 4.03s
# 203:	learn: 1.2390166	total: 1.03s	remaining: 4.02s
# 204:	learn: 1.2387226	total: 1.03s	remaining: 4s
# 205:	learn: 1.2382536	total: 1.03s	remaining: 3.99s
# 206:	learn: 1.2377023	total: 1.04s	remaining: 3.97s
# 207:	learn: 1.2373017	total: 1.04s	remaining: 3.96s
# 208:	learn: 1.2368550	total: 1.04s	remaining: 3.95s
# 209:	learn: 1.2366001	total: 1.05s	remaining: 3.94s
# 210:	learn: 1.2363793	total: 1.05s	remaining: 3.92s
# 211:	learn: 1.2361491	total: 1.05s	remaining: 3.9s
# 212:	learn: 1.2358704	total: 1.05s	remaining: 3.89s
# 213:	learn: 1.2354582	total: 1.06s	remaining: 3.88s
# 214:	learn: 1.2351689	total: 1.06s	remaining: 3.87s
# 215:	learn: 1.2348262	total: 1.06s	remaining: 3.86s
# 216:	learn: 1.2344460	total: 1.06s	remaining: 3.84s
# 217:	learn: 1.2342493	total: 1.07s	remaining: 3.83s
# 218:	learn: 1.2340051	total: 1.07s	remaining: 3.82s
# 219:	learn: 1.2337038	total: 1.07s	remaining: 3.81s
# 220:	learn: 1.2332554	total: 1.08s	remaining: 3.79s
# 221:	learn: 1.2330459	total: 1.08s	remaining: 3.78s
# 222:	learn: 1.2329001	total: 1.08s	remaining: 3.77s
# 223:	learn: 1.2325220	total: 1.08s	remaining: 3.75s
# 224:	learn: 1.2323151	total: 1.09s	remaining: 3.74s
# 225:	learn: 1.2320149	total: 1.09s	remaining: 3.73s
# 226:	learn: 1.2317180	total: 1.09s	remaining: 3.72s
# 227:	learn: 1.2315714	total: 1.09s	remaining: 3.71s
# 228:	learn: 1.2313294	total: 1.1s	remaining: 3.69s
# 229:	learn: 1.2310891	total: 1.1s	remaining: 3.68s
# 230:	learn: 1.2305077	total: 1.1s	remaining: 3.67s
# 231:	learn: 1.2301871	total: 1.1s	remaining: 3.66s
# 232:	learn: 1.2293830	total: 1.11s	remaining: 3.65s
# 233:	learn: 1.2289074	total: 1.11s	remaining: 3.64s
# 234:	learn: 1.2286175	total: 1.11s	remaining: 3.63s
# 235:	learn: 1.2283349	total: 1.12s	remaining: 3.62s
# 236:	learn: 1.2278951	total: 1.12s	remaining: 3.61s
# 237:	learn: 1.2276544	total: 1.12s	remaining: 3.6s
# 238:	learn: 1.2266997	total: 1.13s	remaining: 3.59s
# 239:	learn: 1.2265589	total: 1.13s	remaining: 3.58s
# 240:	learn: 1.2263561	total: 1.13s	remaining: 3.57s
# 241:	learn: 1.2261677	total: 1.14s	remaining: 3.56s
# 242:	learn: 1.2259589	total: 1.14s	remaining: 3.54s
# 243:	learn: 1.2256995	total: 1.14s	remaining: 3.54s
# 244:	learn: 1.2244205	total: 1.14s	remaining: 3.53s
# 245:	learn: 1.2241529	total: 1.15s	remaining: 3.52s
# 246:	learn: 1.2236557	total: 1.15s	remaining: 3.51s
# 247:	learn: 1.2234018	total: 1.15s	remaining: 3.5s
# 248:	learn: 1.2230190	total: 1.16s	remaining: 3.49s
# 249:	learn: 1.2227150	total: 1.16s	remaining: 3.48s
# 250:	learn: 1.2225240	total: 1.16s	remaining: 3.47s
# 251:	learn: 1.2223298	total: 1.17s	remaining: 3.47s
# 252:	learn: 1.2220814	total: 1.17s	remaining: 3.46s
# 253:	learn: 1.2218348	total: 1.17s	remaining: 3.45s
# 254:	learn: 1.2216457	total: 1.18s	remaining: 3.44s
# 255:	learn: 1.2213326	total: 1.18s	remaining: 3.43s
# 256:	learn: 1.2211530	total: 1.19s	remaining: 3.43s
# 257:	learn: 1.2210807	total: 1.19s	remaining: 3.42s
# 258:	learn: 1.2208936	total: 1.19s	remaining: 3.41s
# 259:	learn: 1.2207531	total: 1.19s	remaining: 3.4s
# 260:	learn: 1.2205376	total: 1.2s	remaining: 3.4s
# 261:	learn: 1.2202177	total: 1.21s	remaining: 3.4s
# 262:	learn: 1.2196217	total: 1.21s	remaining: 3.4s
# 263:	learn: 1.2193858	total: 1.22s	remaining: 3.4s
# 264:	learn: 1.2190174	total: 1.22s	remaining: 3.39s
# 265:	learn: 1.2185786	total: 1.23s	remaining: 3.4s
# 266:	learn: 1.2181695	total: 1.24s	remaining: 3.4s
# 267:	learn: 1.2178979	total: 1.24s	remaining: 3.39s
# 268:	learn: 1.2176069	total: 1.24s	remaining: 3.38s
# 269:	learn: 1.2174785	total: 1.25s	remaining: 3.37s
# 270:	learn: 1.2173061	total: 1.25s	remaining: 3.36s
# 271:	learn: 1.2171587	total: 1.25s	remaining: 3.35s
# 272:	learn: 1.2169060	total: 1.25s	remaining: 3.34s
# 273:	learn: 1.2167584	total: 1.26s	remaining: 3.34s
# 274:	learn: 1.2164446	total: 1.26s	remaining: 3.33s
# 275:	learn: 1.2162573	total: 1.26s	remaining: 3.32s
# 276:	learn: 1.2158953	total: 1.27s	remaining: 3.31s
# 277:	learn: 1.2148966	total: 1.27s	remaining: 3.3s
# 278:	learn: 1.2146557	total: 1.27s	remaining: 3.29s
# 279:	learn: 1.2144864	total: 1.28s	remaining: 3.28s
# 280:	learn: 1.2143178	total: 1.28s	remaining: 3.28s
# 281:	learn: 1.2141530	total: 1.28s	remaining: 3.27s
# 282:	learn: 1.2139691	total: 1.3s	remaining: 3.3s
# 283:	learn: 1.2137066	total: 1.31s	remaining: 3.31s
# 284:	learn: 1.2136284	total: 1.32s	remaining: 3.3s
# 285:	learn: 1.2134329	total: 1.32s	remaining: 3.29s
# 286:	learn: 1.2132579	total: 1.32s	remaining: 3.28s
# 287:	learn: 1.2129378	total: 1.32s	remaining: 3.27s
# 288:	learn: 1.2125357	total: 1.33s	remaining: 3.27s
# 289:	learn: 1.2124058	total: 1.33s	remaining: 3.26s
# 290:	learn: 1.2123191	total: 1.33s	remaining: 3.25s
# 291:	learn: 1.2121140	total: 1.34s	remaining: 3.25s
# 292:	learn: 1.2120412	total: 1.34s	remaining: 3.24s
# 293:	learn: 1.2110678	total: 1.35s	remaining: 3.23s
# 294:	learn: 1.2107132	total: 1.35s	remaining: 3.22s
# 295:	learn: 1.2105239	total: 1.35s	remaining: 3.22s
# 296:	learn: 1.2103469	total: 1.36s	remaining: 3.21s
# 297:	learn: 1.2100906	total: 1.36s	remaining: 3.21s
# 298:	learn: 1.2098805	total: 1.36s	remaining: 3.2s
# 299:	learn: 1.2097107	total: 1.37s	remaining: 3.19s
# 300:	learn: 1.2095075	total: 1.37s	remaining: 3.18s
# 301:	learn: 1.2093899	total: 1.37s	remaining: 3.17s
# 302:	learn: 1.2091973	total: 1.38s	remaining: 3.17s
# 303:	learn: 1.2090405	total: 1.38s	remaining: 3.16s
# 304:	learn: 1.2088274	total: 1.38s	remaining: 3.15s
# 305:	learn: 1.2085976	total: 1.39s	remaining: 3.15s
# 306:	learn: 1.2084891	total: 1.39s	remaining: 3.14s
# 307:	learn: 1.2081871	total: 1.4s	remaining: 3.14s
# 308:	learn: 1.2079465	total: 1.4s	remaining: 3.13s
# 309:	learn: 1.2076581	total: 1.4s	remaining: 3.12s
# 310:	learn: 1.2074944	total: 1.41s	remaining: 3.12s
# 311:	learn: 1.2073086	total: 1.41s	remaining: 3.11s
# 312:	learn: 1.2070495	total: 1.42s	remaining: 3.11s
# 313:	learn: 1.2069177	total: 1.42s	remaining: 3.1s
# 314:	learn: 1.2067698	total: 1.42s	remaining: 3.1s
# 315:	learn: 1.2065918	total: 1.43s	remaining: 3.09s
# 316:	learn: 1.2064016	total: 1.43s	remaining: 3.08s
# 317:	learn: 1.2062771	total: 1.44s	remaining: 3.08s
# 318:	learn: 1.2051649	total: 1.44s	remaining: 3.07s
# 319:	learn: 1.2050017	total: 1.44s	remaining: 3.07s
# 320:	learn: 1.2046874	total: 1.45s	remaining: 3.06s
# 321:	learn: 1.2044198	total: 1.45s	remaining: 3.05s
# 322:	learn: 1.2043015	total: 1.45s	remaining: 3.04s
# 323:	learn: 1.2041538	total: 1.46s	remaining: 3.04s
# 324:	learn: 1.2041189	total: 1.46s	remaining: 3.03s
# 325:	learn: 1.2039445	total: 1.46s	remaining: 3.02s
# 326:	learn: 1.2037494	total: 1.46s	remaining: 3.01s
# 327:	learn: 1.2034534	total: 1.47s	remaining: 3.01s
# 328:	learn: 1.2032656	total: 1.47s	remaining: 3s
# 329:	learn: 1.2030747	total: 1.47s	remaining: 2.99s
# 330:	learn: 1.2028936	total: 1.48s	remaining: 2.98s
# 331:	learn: 1.2025871	total: 1.48s	remaining: 2.97s
# 332:	learn: 1.2024370	total: 1.48s	remaining: 2.96s
# 333:	learn: 1.2022002	total: 1.48s	remaining: 2.96s
# 334:	learn: 1.2020493	total: 1.48s	remaining: 2.95s
# 335:	learn: 1.2018805	total: 1.49s	remaining: 2.94s
# 336:	learn: 1.2016656	total: 1.49s	remaining: 2.93s
# 337:	learn: 1.2015891	total: 1.49s	remaining: 2.92s
# 338:	learn: 1.2013154	total: 1.5s	remaining: 2.92s
# 339:	learn: 1.2011347	total: 1.5s	remaining: 2.91s
# 340:	learn: 1.2009565	total: 1.5s	remaining: 2.9s
# 341:	learn: 1.2007991	total: 1.5s	remaining: 2.89s
# 342:	learn: 1.2006007	total: 1.5s	remaining: 2.88s
# 343:	learn: 1.2003126	total: 1.51s	remaining: 2.88s
# 344:	learn: 1.2001670	total: 1.51s	remaining: 2.87s
# 345:	learn: 1.1998645	total: 1.51s	remaining: 2.86s
# 346:	learn: 1.1996051	total: 1.52s	remaining: 2.85s
# 347:	learn: 1.1993991	total: 1.52s	remaining: 2.85s
# 348:	learn: 1.1993646	total: 1.52s	remaining: 2.84s
# 349:	learn: 1.1991232	total: 1.52s	remaining: 2.83s
# 350:	learn: 1.1989688	total: 1.53s	remaining: 2.82s
# 351:	learn: 1.1988117	total: 1.53s	remaining: 2.82s
# 352:	learn: 1.1985685	total: 1.53s	remaining: 2.81s
# 353:	learn: 1.1983368	total: 1.54s	remaining: 2.8s
# 354:	learn: 1.1981218	total: 1.54s	remaining: 2.8s
# 355:	learn: 1.1979958	total: 1.54s	remaining: 2.79s
# 356:	learn: 1.1977669	total: 1.54s	remaining: 2.78s
# 357:	learn: 1.1975976	total: 1.55s	remaining: 2.78s
# 358:	learn: 1.1973642	total: 1.55s	remaining: 2.77s
# 359:	learn: 1.1967743	total: 1.55s	remaining: 2.76s
# 360:	learn: 1.1966207	total: 1.56s	remaining: 2.75s
# 361:	learn: 1.1964564	total: 1.56s	remaining: 2.75s
# 362:	learn: 1.1962043	total: 1.56s	remaining: 2.74s
# 363:	learn: 1.1960517	total: 1.56s	remaining: 2.73s
# 364:	learn: 1.1958844	total: 1.57s	remaining: 2.73s
# 365:	learn: 1.1954558	total: 1.57s	remaining: 2.72s
# 366:	learn: 1.1952601	total: 1.58s	remaining: 2.72s
# 367:	learn: 1.1950847	total: 1.58s	remaining: 2.71s
# 368:	learn: 1.1948955	total: 1.58s	remaining: 2.71s
# 369:	learn: 1.1946660	total: 1.59s	remaining: 2.7s
# 370:	learn: 1.1944704	total: 1.59s	remaining: 2.7s
# 371:	learn: 1.1942584	total: 1.59s	remaining: 2.69s
# 372:	learn: 1.1939702	total: 1.6s	remaining: 2.69s
# 373:	learn: 1.1936464	total: 1.6s	remaining: 2.68s
# 374:	learn: 1.1933964	total: 1.61s	remaining: 2.68s
# 375:	learn: 1.1931991	total: 1.61s	remaining: 2.68s
# 376:	learn: 1.1930540	total: 1.62s	remaining: 2.67s
# 377:	learn: 1.1928698	total: 1.62s	remaining: 2.67s
# 378:	learn: 1.1926920	total: 1.63s	remaining: 2.66s
# 379:	learn: 1.1915937	total: 1.63s	remaining: 2.66s
# 380:	learn: 1.1914768	total: 1.63s	remaining: 2.65s
# 381:	learn: 1.1913013	total: 1.64s	remaining: 2.65s
# 382:	learn: 1.1911646	total: 1.64s	remaining: 2.65s
# 383:	learn: 1.1908864	total: 1.65s	remaining: 2.64s
# 384:	learn: 1.1906712	total: 1.65s	remaining: 2.64s
# 385:	learn: 1.1905336	total: 1.65s	remaining: 2.63s
# 386:	learn: 1.1903779	total: 1.66s	remaining: 2.63s
# 387:	learn: 1.1902085	total: 1.66s	remaining: 2.62s
# 388:	learn: 1.1900544	total: 1.66s	remaining: 2.61s
# 389:	learn: 1.1898180	total: 1.67s	remaining: 2.61s
# 390:	learn: 1.1895661	total: 1.67s	remaining: 2.6s
# 391:	learn: 1.1893576	total: 1.67s	remaining: 2.59s
# 392:	learn: 1.1891743	total: 1.68s	remaining: 2.59s
# 393:	learn: 1.1879375	total: 1.68s	remaining: 2.58s
# 394:	learn: 1.1877416	total: 1.68s	remaining: 2.57s
# 395:	learn: 1.1875447	total: 1.68s	remaining: 2.57s
# 396:	learn: 1.1874063	total: 1.69s	remaining: 2.56s
# 397:	learn: 1.1872360	total: 1.69s	remaining: 2.56s
# 398:	learn: 1.1870907	total: 1.69s	remaining: 2.55s
# 399:	learn: 1.1869338	total: 1.7s	remaining: 2.54s
# 400:	learn: 1.1867182	total: 1.7s	remaining: 2.54s
# 401:	learn: 1.1864819	total: 1.7s	remaining: 2.53s
# 402:	learn: 1.1863014	total: 1.7s	remaining: 2.52s
# 403:	learn: 1.1861781	total: 1.71s	remaining: 2.52s
# 404:	learn: 1.1852748	total: 1.71s	remaining: 2.51s
# 405:	learn: 1.1849088	total: 1.71s	remaining: 2.51s
# 406:	learn: 1.1847616	total: 1.72s	remaining: 2.5s
# 407:	learn: 1.1846138	total: 1.72s	remaining: 2.5s
# 408:	learn: 1.1844718	total: 1.72s	remaining: 2.49s
# 409:	learn: 1.1843427	total: 1.73s	remaining: 2.48s
# 410:	learn: 1.1837288	total: 1.73s	remaining: 2.48s
# 411:	learn: 1.1836210	total: 1.73s	remaining: 2.47s
# 412:	learn: 1.1834447	total: 1.73s	remaining: 2.46s
# 413:	learn: 1.1833616	total: 1.74s	remaining: 2.46s
# 414:	learn: 1.1831129	total: 1.74s	remaining: 2.45s
# 415:	learn: 1.1829879	total: 1.74s	remaining: 2.45s
# 416:	learn: 1.1828590	total: 1.75s	remaining: 2.44s
# 417:	learn: 1.1827246	total: 1.75s	remaining: 2.44s
# 418:	learn: 1.1820722	total: 1.75s	remaining: 2.43s
# 419:	learn: 1.1819579	total: 1.75s	remaining: 2.42s
# 420:	learn: 1.1817197	total: 1.76s	remaining: 2.42s
# 421:	learn: 1.1815726	total: 1.76s	remaining: 2.41s
# 422:	learn: 1.1814163	total: 1.76s	remaining: 2.41s
# 423:	learn: 1.1813098	total: 1.77s	remaining: 2.4s
# 424:	learn: 1.1810916	total: 1.77s	remaining: 2.4s
# 425:	learn: 1.1809074	total: 1.77s	remaining: 2.39s
# 426:	learn: 1.1807866	total: 1.78s	remaining: 2.38s
# 427:	learn: 1.1806656	total: 1.78s	remaining: 2.38s
# 428:	learn: 1.1803880	total: 1.78s	remaining: 2.37s
# 429:	learn: 1.1801838	total: 1.79s	remaining: 2.37s
# 430:	learn: 1.1799152	total: 1.79s	remaining: 2.36s
# 431:	learn: 1.1797965	total: 1.79s	remaining: 2.36s
# 432:	learn: 1.1796627	total: 1.79s	remaining: 2.35s
# 433:	learn: 1.1794496	total: 1.8s	remaining: 2.35s
# 434:	learn: 1.1793210	total: 1.8s	remaining: 2.34s
# 435:	learn: 1.1791856	total: 1.8s	remaining: 2.33s
# 436:	learn: 1.1790112	total: 1.81s	remaining: 2.33s
# 437:	learn: 1.1788461	total: 1.81s	remaining: 2.32s
# 438:	learn: 1.1787312	total: 1.81s	remaining: 2.31s
# 439:	learn: 1.1786131	total: 1.81s	remaining: 2.31s
# 440:	learn: 1.1783024	total: 1.82s	remaining: 2.3s
# 441:	learn: 1.1781227	total: 1.82s	remaining: 2.3s
# 442:	learn: 1.1780335	total: 1.82s	remaining: 2.29s
# 443:	learn: 1.1778408	total: 1.83s	remaining: 2.29s
# 444:	learn: 1.1777185	total: 1.83s	remaining: 2.28s
# 445:	learn: 1.1775931	total: 1.83s	remaining: 2.27s
# 446:	learn: 1.1775213	total: 1.83s	remaining: 2.27s
# 447:	learn: 1.1774425	total: 1.83s	remaining: 2.26s
# 448:	learn: 1.1772719	total: 1.84s	remaining: 2.25s
# 449:	learn: 1.1770451	total: 1.84s	remaining: 2.25s
# 450:	learn: 1.1768365	total: 1.84s	remaining: 2.24s
# 451:	learn: 1.1767631	total: 1.84s	remaining: 2.24s
# 452:	learn: 1.1766889	total: 1.85s	remaining: 2.23s
# 453:	learn: 1.1765124	total: 1.85s	remaining: 2.22s
# 454:	learn: 1.1764637	total: 1.85s	remaining: 2.22s
# 455:	learn: 1.1763036	total: 1.85s	remaining: 2.21s
# 456:	learn: 1.1761090	total: 1.86s	remaining: 2.21s
# 457:	learn: 1.1758834	total: 1.86s	remaining: 2.2s
# 458:	learn: 1.1758368	total: 1.86s	remaining: 2.19s
# 459:	learn: 1.1756721	total: 1.86s	remaining: 2.19s
# 460:	learn: 1.1753888	total: 1.87s	remaining: 2.18s
# 461:	learn: 1.1752603	total: 1.87s	remaining: 2.18s
# 462:	learn: 1.1750763	total: 1.87s	remaining: 2.17s
# 463:	learn: 1.1747917	total: 1.88s	remaining: 2.17s
# 464:	learn: 1.1745881	total: 1.88s	remaining: 2.16s
# 465:	learn: 1.1744364	total: 1.88s	remaining: 2.15s
# 466:	learn: 1.1743200	total: 1.88s	remaining: 2.15s
# 467:	learn: 1.1741929	total: 1.89s	remaining: 2.14s
# 468:	learn: 1.1740336	total: 1.89s	remaining: 2.14s
# 469:	learn: 1.1737828	total: 1.89s	remaining: 2.13s
# 470:	learn: 1.1724848	total: 1.89s	remaining: 2.13s
# 471:	learn: 1.1723052	total: 1.89s	remaining: 2.12s
# 472:	learn: 1.1719988	total: 1.9s	remaining: 2.11s
# 473:	learn: 1.1718385	total: 1.9s	remaining: 2.11s
# 474:	learn: 1.1716583	total: 1.9s	remaining: 2.1s
# 475:	learn: 1.1714952	total: 1.9s	remaining: 2.09s
# 476:	learn: 1.1713280	total: 1.91s	remaining: 2.09s
# 477:	learn: 1.1711581	total: 1.91s	remaining: 2.08s
# 478:	learn: 1.1710422	total: 1.91s	remaining: 2.08s
# 479:	learn: 1.1703077	total: 1.92s	remaining: 2.07s
# 480:	learn: 1.1701561	total: 1.92s	remaining: 2.07s
# 481:	learn: 1.1700015	total: 1.92s	remaining: 2.06s
# 482:	learn: 1.1698727	total: 1.92s	remaining: 2.06s
# 483:	learn: 1.1696469	total: 1.93s	remaining: 2.05s
# 484:	learn: 1.1695405	total: 1.93s	remaining: 2.05s
# 485:	learn: 1.1693313	total: 1.93s	remaining: 2.04s
# 486:	learn: 1.1690479	total: 1.93s	remaining: 2.04s
# 487:	learn: 1.1688245	total: 1.94s	remaining: 2.03s
# 488:	learn: 1.1686309	total: 1.94s	remaining: 2.03s
# 489:	learn: 1.1684667	total: 1.94s	remaining: 2.02s
# 490:	learn: 1.1681875	total: 1.95s	remaining: 2.02s
# 491:	learn: 1.1680039	total: 1.95s	remaining: 2.01s
# 492:	learn: 1.1678776	total: 1.95s	remaining: 2.01s
# 493:	learn: 1.1675999	total: 1.96s	remaining: 2s
# 494:	learn: 1.1674195	total: 1.96s	remaining: 2s
# 495:	learn: 1.1673213	total: 1.96s	remaining: 2s
# 496:	learn: 1.1672054	total: 1.97s	remaining: 1.99s
# 497:	learn: 1.1670442	total: 1.97s	remaining: 1.99s
# 498:	learn: 1.1668770	total: 1.98s	remaining: 1.98s
# 499:	learn: 1.1666581	total: 1.98s	remaining: 1.98s
# 500:	learn: 1.1665002	total: 1.99s	remaining: 1.98s
# 501:	learn: 1.1663754	total: 1.99s	remaining: 1.97s
# 502:	learn: 1.1661958	total: 1.99s	remaining: 1.97s
# 503:	learn: 1.1653215	total: 2s	remaining: 1.96s
# 504:	learn: 1.1651585	total: 2s	remaining: 1.96s
# 505:	learn: 1.1649283	total: 2s	remaining: 1.96s
# 506:	learn: 1.1647427	total: 2.01s	remaining: 1.95s
# 507:	learn: 1.1645221	total: 2.01s	remaining: 1.95s
# 508:	learn: 1.1644328	total: 2.02s	remaining: 1.95s
# 509:	learn: 1.1643185	total: 2.02s	remaining: 1.94s
# 510:	learn: 1.1641537	total: 2.02s	remaining: 1.94s
# 511:	learn: 1.1640024	total: 2.02s	remaining: 1.93s
# 512:	learn: 1.1637620	total: 2.03s	remaining: 1.93s
# 513:	learn: 1.1636234	total: 2.03s	remaining: 1.92s
# 514:	learn: 1.1635287	total: 2.03s	remaining: 1.92s
# 515:	learn: 1.1633893	total: 2.04s	remaining: 1.91s
# 516:	learn: 1.1630790	total: 2.04s	remaining: 1.9s
# 517:	learn: 1.1629965	total: 2.04s	remaining: 1.9s
# 518:	learn: 1.1628523	total: 2.04s	remaining: 1.89s
# 519:	learn: 1.1623392	total: 2.05s	remaining: 1.89s
# 520:	learn: 1.1622135	total: 2.05s	remaining: 1.89s
# 521:	learn: 1.1620035	total: 2.05s	remaining: 1.88s
# 522:	learn: 1.1618849	total: 2.06s	remaining: 1.88s
# 523:	learn: 1.1617581	total: 2.06s	remaining: 1.87s
# 524:	learn: 1.1616668	total: 2.06s	remaining: 1.87s
# 525:	learn: 1.1614347	total: 2.07s	remaining: 1.86s
# 526:	learn: 1.1612923	total: 2.07s	remaining: 1.86s
# 527:	learn: 1.1610452	total: 2.08s	remaining: 1.85s
# 528:	learn: 1.1608259	total: 2.08s	remaining: 1.85s
# 529:	learn: 1.1606552	total: 2.08s	remaining: 1.85s
# 530:	learn: 1.1605028	total: 2.08s	remaining: 1.84s
# 531:	learn: 1.1603047	total: 2.09s	remaining: 1.84s
# 532:	learn: 1.1596157	total: 2.09s	remaining: 1.83s
# 533:	learn: 1.1594662	total: 2.09s	remaining: 1.83s
# 534:	learn: 1.1592824	total: 2.1s	remaining: 1.82s
# 535:	learn: 1.1591178	total: 2.1s	remaining: 1.82s
# 536:	learn: 1.1590338	total: 2.1s	remaining: 1.81s
# 537:	learn: 1.1589656	total: 2.1s	remaining: 1.81s
# 538:	learn: 1.1587620	total: 2.11s	remaining: 1.8s
# 539:	learn: 1.1582791	total: 2.11s	remaining: 1.8s
# 540:	learn: 1.1581778	total: 2.12s	remaining: 1.79s
# 541:	learn: 1.1580953	total: 2.12s	remaining: 1.79s
# 542:	learn: 1.1579428	total: 2.12s	remaining: 1.78s
# 543:	learn: 1.1578244	total: 2.12s	remaining: 1.78s
# 544:	learn: 1.1577236	total: 2.13s	remaining: 1.77s
# 545:	learn: 1.1575473	total: 2.13s	remaining: 1.77s
# 546:	learn: 1.1572531	total: 2.13s	remaining: 1.76s
# 547:	learn: 1.1570492	total: 2.13s	remaining: 1.76s
# 548:	learn: 1.1569120	total: 2.14s	remaining: 1.76s
# 549:	learn: 1.1567790	total: 2.14s	remaining: 1.75s
# 550:	learn: 1.1566617	total: 2.15s	remaining: 1.75s
# 551:	learn: 1.1564819	total: 2.15s	remaining: 1.74s
# 552:	learn: 1.1563361	total: 2.15s	remaining: 1.74s
# 553:	learn: 1.1562605	total: 2.15s	remaining: 1.73s
# 554:	learn: 1.1560905	total: 2.16s	remaining: 1.73s
# 555:	learn: 1.1560025	total: 2.16s	remaining: 1.73s
# 556:	learn: 1.1558863	total: 2.17s	remaining: 1.72s
# 557:	learn: 1.1556989	total: 2.17s	remaining: 1.72s
# 558:	learn: 1.1556267	total: 2.17s	remaining: 1.71s
# 559:	learn: 1.1555145	total: 2.18s	remaining: 1.71s
# 560:	learn: 1.1552908	total: 2.18s	remaining: 1.71s
# 561:	learn: 1.1546201	total: 2.18s	remaining: 1.7s
# 562:	learn: 1.1544825	total: 2.19s	remaining: 1.7s
# 563:	learn: 1.1543097	total: 2.19s	remaining: 1.69s
# 564:	learn: 1.1541597	total: 2.19s	remaining: 1.69s
# 565:	learn: 1.1540382	total: 2.2s	remaining: 1.68s
# 566:	learn: 1.1537868	total: 2.2s	remaining: 1.68s
# 567:	learn: 1.1537086	total: 2.2s	remaining: 1.68s
# 568:	learn: 1.1534967	total: 2.21s	remaining: 1.67s
# 569:	learn: 1.1534746	total: 2.21s	remaining: 1.67s
# 570:	learn: 1.1533489	total: 2.21s	remaining: 1.66s
# 571:	learn: 1.1532146	total: 2.22s	remaining: 1.66s
# 572:	learn: 1.1530697	total: 2.22s	remaining: 1.66s
# 573:	learn: 1.1528014	total: 2.23s	remaining: 1.65s
# 574:	learn: 1.1526978	total: 2.23s	remaining: 1.65s
# 575:	learn: 1.1525289	total: 2.23s	remaining: 1.64s
# 576:	learn: 1.1523868	total: 2.23s	remaining: 1.64s
# 577:	learn: 1.1522098	total: 2.24s	remaining: 1.63s
# 578:	learn: 1.1519822	total: 2.24s	remaining: 1.63s
# 579:	learn: 1.1518841	total: 2.24s	remaining: 1.63s
# 580:	learn: 1.1517463	total: 2.25s	remaining: 1.62s
# 581:	learn: 1.1513297	total: 2.25s	remaining: 1.61s
# 582:	learn: 1.1512088	total: 2.25s	remaining: 1.61s
# 583:	learn: 1.1510764	total: 2.25s	remaining: 1.61s
# 584:	learn: 1.1508887	total: 2.26s	remaining: 1.6s
# 585:	learn: 1.1506986	total: 2.26s	remaining: 1.6s
# 586:	learn: 1.1505011	total: 2.26s	remaining: 1.59s
# 587:	learn: 1.1504671	total: 2.27s	remaining: 1.59s
# 588:	learn: 1.1502682	total: 2.27s	remaining: 1.58s
# 589:	learn: 1.1500491	total: 2.27s	remaining: 1.58s
# 590:	learn: 1.1499470	total: 2.27s	remaining: 1.57s
# 591:	learn: 1.1496680	total: 2.27s	remaining: 1.57s
# 592:	learn: 1.1494882	total: 2.28s	remaining: 1.56s
# 593:	learn: 1.1493956	total: 2.28s	remaining: 1.56s
# 594:	learn: 1.1492832	total: 2.28s	remaining: 1.55s
# 595:	learn: 1.1490583	total: 2.29s	remaining: 1.55s
# 596:	learn: 1.1489030	total: 2.29s	remaining: 1.54s
# 597:	learn: 1.1487559	total: 2.29s	remaining: 1.54s
# 598:	learn: 1.1483263	total: 2.29s	remaining: 1.54s
# 599:	learn: 1.1482649	total: 2.3s	remaining: 1.53s
# 600:	learn: 1.1481075	total: 2.3s	remaining: 1.53s
# 601:	learn: 1.1480432	total: 2.3s	remaining: 1.52s
# 602:	learn: 1.1478184	total: 2.31s	remaining: 1.52s
# 603:	learn: 1.1477115	total: 2.31s	remaining: 1.51s
# 604:	learn: 1.1476008	total: 2.31s	remaining: 1.51s
# 605:	learn: 1.1475004	total: 2.31s	remaining: 1.5s
# 606:	learn: 1.1473570	total: 2.31s	remaining: 1.5s
# 607:	learn: 1.1472124	total: 2.32s	remaining: 1.49s
# 608:	learn: 1.1470307	total: 2.32s	remaining: 1.49s
# 609:	learn: 1.1469018	total: 2.32s	remaining: 1.49s
# 610:	learn: 1.1467722	total: 2.33s	remaining: 1.48s
# 611:	learn: 1.1466468	total: 2.33s	remaining: 1.48s
# 612:	learn: 1.1465421	total: 2.33s	remaining: 1.47s
# 613:	learn: 1.1463959	total: 2.34s	remaining: 1.47s
# 614:	learn: 1.1462213	total: 2.34s	remaining: 1.46s
# 615:	learn: 1.1461086	total: 2.34s	remaining: 1.46s
# 616:	learn: 1.1459828	total: 2.35s	remaining: 1.46s
# 617:	learn: 1.1458843	total: 2.35s	remaining: 1.45s
# 618:	learn: 1.1457865	total: 2.35s	remaining: 1.45s
# 619:	learn: 1.1457032	total: 2.35s	remaining: 1.44s
# 620:	learn: 1.1455586	total: 2.36s	remaining: 1.44s
# 621:	learn: 1.1453590	total: 2.36s	remaining: 1.44s
# 622:	learn: 1.1452103	total: 2.37s	remaining: 1.43s
# 623:	learn: 1.1451098	total: 2.37s	remaining: 1.43s
# 624:	learn: 1.1449830	total: 2.38s	remaining: 1.43s
# 625:	learn: 1.1448482	total: 2.38s	remaining: 1.42s
# 626:	learn: 1.1447044	total: 2.38s	remaining: 1.42s
# 627:	learn: 1.1446077	total: 2.39s	remaining: 1.42s
# 628:	learn: 1.1444773	total: 2.39s	remaining: 1.41s
# 629:	learn: 1.1443749	total: 2.4s	remaining: 1.41s
# 630:	learn: 1.1443028	total: 2.4s	remaining: 1.41s
# 631:	learn: 1.1441374	total: 2.41s	remaining: 1.4s
# 632:	learn: 1.1440069	total: 2.41s	remaining: 1.4s
# 633:	learn: 1.1438386	total: 2.42s	remaining: 1.39s
# 634:	learn: 1.1437277	total: 2.42s	remaining: 1.39s
# 635:	learn: 1.1435106	total: 2.42s	remaining: 1.39s
# 636:	learn: 1.1432989	total: 2.42s	remaining: 1.38s
# 637:	learn: 1.1431612	total: 2.43s	remaining: 1.38s
# 638:	learn: 1.1424268	total: 2.43s	remaining: 1.37s
# 639:	learn: 1.1423154	total: 2.43s	remaining: 1.37s
# 640:	learn: 1.1421996	total: 2.44s	remaining: 1.36s
# 641:	learn: 1.1420698	total: 2.44s	remaining: 1.36s
# 642:	learn: 1.1418568	total: 2.44s	remaining: 1.36s
# 643:	learn: 1.1417752	total: 2.44s	remaining: 1.35s
# 644:	learn: 1.1416329	total: 2.45s	remaining: 1.35s
# 645:	learn: 1.1414864	total: 2.45s	remaining: 1.34s
# 646:	learn: 1.1413831	total: 2.45s	remaining: 1.34s
# 647:	learn: 1.1412014	total: 2.46s	remaining: 1.33s
# 648:	learn: 1.1410179	total: 2.46s	remaining: 1.33s
# 649:	learn: 1.1409019	total: 2.46s	remaining: 1.32s
# 650:	learn: 1.1407962	total: 2.46s	remaining: 1.32s
# 651:	learn: 1.1405909	total: 2.47s	remaining: 1.32s
# 652:	learn: 1.1403612	total: 2.47s	remaining: 1.31s
# 653:	learn: 1.1402665	total: 2.47s	remaining: 1.31s
# 654:	learn: 1.1401257	total: 2.47s	remaining: 1.3s
# 655:	learn: 1.1400258	total: 2.48s	remaining: 1.3s
# 656:	learn: 1.1398311	total: 2.48s	remaining: 1.29s
# 657:	learn: 1.1397734	total: 2.48s	remaining: 1.29s
# 658:	learn: 1.1396772	total: 2.49s	remaining: 1.29s
# 659:	learn: 1.1394777	total: 2.49s	remaining: 1.28s
# 660:	learn: 1.1393308	total: 2.5s	remaining: 1.28s
# 661:	learn: 1.1391442	total: 2.5s	remaining: 1.27s
# 662:	learn: 1.1389610	total: 2.5s	remaining: 1.27s
# 663:	learn: 1.1388004	total: 2.5s	remaining: 1.27s
# 664:	learn: 1.1386007	total: 2.5s	remaining: 1.26s
# 665:	learn: 1.1385075	total: 2.51s	remaining: 1.26s
# 666:	learn: 1.1383455	total: 2.51s	remaining: 1.25s
# 667:	learn: 1.1382431	total: 2.52s	remaining: 1.25s
# 668:	learn: 1.1380964	total: 2.52s	remaining: 1.25s
# 669:	learn: 1.1379904	total: 2.52s	remaining: 1.24s
# 670:	learn: 1.1378425	total: 2.52s	remaining: 1.24s
# 671:	learn: 1.1376140	total: 2.53s	remaining: 1.23s
# 672:	learn: 1.1374950	total: 2.53s	remaining: 1.23s
# 673:	learn: 1.1371493	total: 2.53s	remaining: 1.23s
# 674:	learn: 1.1370087	total: 2.54s	remaining: 1.22s
# 675:	learn: 1.1368633	total: 2.54s	remaining: 1.22s
# 676:	learn: 1.1367854	total: 2.55s	remaining: 1.21s
# 677:	learn: 1.1366177	total: 2.55s	remaining: 1.21s
# 678:	learn: 1.1364976	total: 2.55s	remaining: 1.21s
# 679:	learn: 1.1362631	total: 2.56s	remaining: 1.2s
# 680:	learn: 1.1361756	total: 2.56s	remaining: 1.2s
# 681:	learn: 1.1360395	total: 2.56s	remaining: 1.2s
# 682:	learn: 1.1354439	total: 2.57s	remaining: 1.19s
# 683:	learn: 1.1352105	total: 2.57s	remaining: 1.19s
# 684:	learn: 1.1351169	total: 2.57s	remaining: 1.18s
# 685:	learn: 1.1348833	total: 2.58s	remaining: 1.18s
# 686:	learn: 1.1347526	total: 2.58s	remaining: 1.18s
# 687:	learn: 1.1346158	total: 2.58s	remaining: 1.17s
# 688:	learn: 1.1345425	total: 2.59s	remaining: 1.17s
# 689:	learn: 1.1344261	total: 2.59s	remaining: 1.16s
# 690:	learn: 1.1343076	total: 2.6s	remaining: 1.16s
# 691:	learn: 1.1342000	total: 2.6s	remaining: 1.16s
# 692:	learn: 1.1339420	total: 2.6s	remaining: 1.15s
# 693:	learn: 1.1338491	total: 2.6s	remaining: 1.15s
# 694:	learn: 1.1336702	total: 2.61s	remaining: 1.14s
# 695:	learn: 1.1334689	total: 2.61s	remaining: 1.14s
# 696:	learn: 1.1333471	total: 2.61s	remaining: 1.14s
# 697:	learn: 1.1332434	total: 2.62s	remaining: 1.13s
# 698:	learn: 1.1331374	total: 2.62s	remaining: 1.13s
# 699:	learn: 1.1329921	total: 2.63s	remaining: 1.13s
# 700:	learn: 1.1327752	total: 2.63s	remaining: 1.12s
# 701:	learn: 1.1325918	total: 2.63s	remaining: 1.12s
# 702:	learn: 1.1324979	total: 2.63s	remaining: 1.11s
# 703:	learn: 1.1323658	total: 2.64s	remaining: 1.11s
# 704:	learn: 1.1322106	total: 2.64s	remaining: 1.1s
# 705:	learn: 1.1320746	total: 2.64s	remaining: 1.1s
# 706:	learn: 1.1318817	total: 2.65s	remaining: 1.1s
# 707:	learn: 1.1317133	total: 2.65s	remaining: 1.09s
# 708:	learn: 1.1315975	total: 2.65s	remaining: 1.09s
# 709:	learn: 1.1314462	total: 2.66s	remaining: 1.08s
# 710:	learn: 1.1312680	total: 2.66s	remaining: 1.08s
# 711:	learn: 1.1311687	total: 2.66s	remaining: 1.08s
# 712:	learn: 1.1309821	total: 2.67s	remaining: 1.07s
# 713:	learn: 1.1309053	total: 2.67s	remaining: 1.07s
# 714:	learn: 1.1307474	total: 2.67s	remaining: 1.06s
# 715:	learn: 1.1305998	total: 2.67s	remaining: 1.06s
# 716:	learn: 1.1304089	total: 2.68s	remaining: 1.06s
# 717:	learn: 1.1303481	total: 2.68s	remaining: 1.05s
# 718:	learn: 1.1302575	total: 2.68s	remaining: 1.05s
# 719:	learn: 1.1301711	total: 2.69s	remaining: 1.04s
# 720:	learn: 1.1300764	total: 2.69s	remaining: 1.04s
# 721:	learn: 1.1299893	total: 2.69s	remaining: 1.04s
# 722:	learn: 1.1298385	total: 2.69s	remaining: 1.03s
# 723:	learn: 1.1296929	total: 2.7s	remaining: 1.03s
# 724:	learn: 1.1296310	total: 2.7s	remaining: 1.02s
# 725:	learn: 1.1293789	total: 2.7s	remaining: 1.02s
# 726:	learn: 1.1292273	total: 2.71s	remaining: 1.01s
# 727:	learn: 1.1291113	total: 2.71s	remaining: 1.01s
# 728:	learn: 1.1289787	total: 2.71s	remaining: 1.01s
# 729:	learn: 1.1284086	total: 2.71s	remaining: 1s
# 730:	learn: 1.1282465	total: 2.71s	remaining: 999ms
# 731:	learn: 1.1280861	total: 2.72s	remaining: 995ms
# 732:	learn: 1.1279945	total: 2.72s	remaining: 991ms
# 733:	learn: 1.1278725	total: 2.72s	remaining: 986ms
# 734:	learn: 1.1277340	total: 2.72s	remaining: 982ms
# 735:	learn: 1.1276230	total: 2.73s	remaining: 978ms
# 736:	learn: 1.1275396	total: 2.73s	remaining: 974ms
# 737:	learn: 1.1273912	total: 2.73s	remaining: 970ms
# 738:	learn: 1.1272747	total: 2.73s	remaining: 966ms
# 739:	learn: 1.1271472	total: 2.74s	remaining: 962ms
# 740:	learn: 1.1270367	total: 2.74s	remaining: 958ms
# 741:	learn: 1.1269279	total: 2.74s	remaining: 954ms
# 742:	learn: 1.1268658	total: 2.75s	remaining: 950ms
# 743:	learn: 1.1267848	total: 2.75s	remaining: 946ms
# 744:	learn: 1.1266977	total: 2.75s	remaining: 942ms
# 745:	learn: 1.1266875	total: 2.75s	remaining: 938ms
# 746:	learn: 1.1265206	total: 2.76s	remaining: 934ms
# 747:	learn: 1.1264165	total: 2.76s	remaining: 930ms
# 748:	learn: 1.1263139	total: 2.76s	remaining: 926ms
# 749:	learn: 1.1261422	total: 2.77s	remaining: 922ms
# 750:	learn: 1.1260492	total: 2.77s	remaining: 918ms
# 751:	learn: 1.1258868	total: 2.77s	remaining: 914ms
# 752:	learn: 1.1257549	total: 2.77s	remaining: 910ms
# 753:	learn: 1.1256473	total: 2.78s	remaining: 906ms
# 754:	learn: 1.1255121	total: 2.78s	remaining: 902ms
# 755:	learn: 1.1253512	total: 2.78s	remaining: 898ms
# 756:	learn: 1.1252371	total: 2.79s	remaining: 894ms
# 757:	learn: 1.1251499	total: 2.79s	remaining: 890ms
# 758:	learn: 1.1250702	total: 2.79s	remaining: 886ms
# 759:	learn: 1.1249698	total: 2.79s	remaining: 882ms
# 760:	learn: 1.1248064	total: 2.8s	remaining: 878ms
# 761:	learn: 1.1247049	total: 2.8s	remaining: 874ms
# 762:	learn: 1.1246181	total: 2.8s	remaining: 870ms
# 763:	learn: 1.1245504	total: 2.8s	remaining: 866ms
# 764:	learn: 1.1243764	total: 2.81s	remaining: 862ms
# 765:	learn: 1.1242410	total: 2.81s	remaining: 858ms
# 766:	learn: 1.1241504	total: 2.81s	remaining: 854ms
# 767:	learn: 1.1239655	total: 2.81s	remaining: 851ms
# 768:	learn: 1.1239062	total: 2.82s	remaining: 847ms
# 769:	learn: 1.1238196	total: 2.82s	remaining: 843ms
# 770:	learn: 1.1236492	total: 2.82s	remaining: 839ms
# 771:	learn: 1.1235207	total: 2.83s	remaining: 835ms
# 772:	learn: 1.1233940	total: 2.83s	remaining: 831ms
# 773:	learn: 1.1232871	total: 2.83s	remaining: 827ms
# 774:	learn: 1.1231015	total: 2.83s	remaining: 823ms
# 775:	learn: 1.1228043	total: 2.84s	remaining: 820ms
# 776:	learn: 1.1227185	total: 2.84s	remaining: 816ms
# 777:	learn: 1.1225554	total: 2.85s	remaining: 812ms
# 778:	learn: 1.1223666	total: 2.85s	remaining: 809ms
# 779:	learn: 1.1222006	total: 2.85s	remaining: 805ms
# 780:	learn: 1.1221239	total: 2.86s	remaining: 801ms
# 781:	learn: 1.1220186	total: 2.86s	remaining: 797ms
# 782:	learn: 1.1218548	total: 2.86s	remaining: 793ms
# 783:	learn: 1.1217253	total: 2.87s	remaining: 789ms
# 784:	learn: 1.1216021	total: 2.87s	remaining: 785ms
# 785:	learn: 1.1214460	total: 2.87s	remaining: 782ms
# 786:	learn: 1.1213059	total: 2.88s	remaining: 779ms
# 787:	learn: 1.1212268	total: 2.88s	remaining: 776ms
# 788:	learn: 1.1211277	total: 2.89s	remaining: 772ms
# 789:	learn: 1.1210715	total: 2.89s	remaining: 768ms
# 790:	learn: 1.1209737	total: 2.89s	remaining: 765ms
# 791:	learn: 1.1208925	total: 2.9s	remaining: 761ms
# 792:	learn: 1.1207592	total: 2.9s	remaining: 757ms
# 793:	learn: 1.1206889	total: 2.9s	remaining: 753ms
# 794:	learn: 1.1206184	total: 2.91s	remaining: 750ms
# 795:	learn: 1.1204253	total: 2.91s	remaining: 746ms
# 796:	learn: 1.1203341	total: 2.91s	remaining: 742ms
# 797:	learn: 1.1201645	total: 2.92s	remaining: 738ms
# 798:	learn: 1.1200817	total: 2.92s	remaining: 734ms
# 799:	learn: 1.1199511	total: 2.92s	remaining: 731ms
# 800:	learn: 1.1197855	total: 2.93s	remaining: 727ms
# 801:	learn: 1.1196338	total: 2.93s	remaining: 723ms
# 802:	learn: 1.1195457	total: 2.93s	remaining: 720ms
# 803:	learn: 1.1194210	total: 2.94s	remaining: 716ms
# 804:	learn: 1.1192888	total: 2.94s	remaining: 713ms
# 805:	learn: 1.1191634	total: 2.95s	remaining: 709ms
# 806:	learn: 1.1190458	total: 2.95s	remaining: 706ms
# 807:	learn: 1.1188607	total: 2.96s	remaining: 702ms
# 808:	learn: 1.1187865	total: 2.96s	remaining: 699ms
# 809:	learn: 1.1185945	total: 2.96s	remaining: 695ms
# 810:	learn: 1.1184559	total: 2.97s	remaining: 692ms
# 811:	learn: 1.1184332	total: 2.97s	remaining: 688ms
# 812:	learn: 1.1183934	total: 2.98s	remaining: 685ms
# 813:	learn: 1.1182559	total: 2.98s	remaining: 682ms
# 814:	learn: 1.1181323	total: 2.99s	remaining: 678ms
# 815:	learn: 1.1180138	total: 2.99s	remaining: 674ms
# 816:	learn: 1.1178734	total: 2.99s	remaining: 670ms
# 817:	learn: 1.1177385	total: 2.99s	remaining: 666ms
# 818:	learn: 1.1176223	total: 3s	remaining: 662ms
# 819:	learn: 1.1175249	total: 3s	remaining: 658ms
# 820:	learn: 1.1174736	total: 3s	remaining: 655ms
# 821:	learn: 1.1173290	total: 3s	remaining: 651ms
# 822:	learn: 1.1171877	total: 3.01s	remaining: 647ms
# 823:	learn: 1.1170450	total: 3.01s	remaining: 643ms
# 824:	learn: 1.1168994	total: 3.01s	remaining: 639ms
# 825:	learn: 1.1167694	total: 3.02s	remaining: 635ms
# 826:	learn: 1.1166792	total: 3.02s	remaining: 631ms
# 827:	learn: 1.1165636	total: 3.02s	remaining: 627ms
# 828:	learn: 1.1160511	total: 3.02s	remaining: 624ms
# 829:	learn: 1.1159038	total: 3.03s	remaining: 620ms
# 830:	learn: 1.1157982	total: 3.03s	remaining: 616ms
# 831:	learn: 1.1156773	total: 3.03s	remaining: 612ms
# 832:	learn: 1.1155611	total: 3.03s	remaining: 608ms
# 833:	learn: 1.1154778	total: 3.04s	remaining: 605ms
# 834:	learn: 1.1154109	total: 3.04s	remaining: 601ms
# 835:	learn: 1.1153704	total: 3.04s	remaining: 597ms
# 836:	learn: 1.1152444	total: 3.05s	remaining: 594ms
# 837:	learn: 1.1151477	total: 3.05s	remaining: 590ms
# 838:	learn: 1.1149714	total: 3.06s	remaining: 586ms
# 839:	learn: 1.1149358	total: 3.06s	remaining: 583ms
# 840:	learn: 1.1148628	total: 3.06s	remaining: 580ms
# 841:	learn: 1.1148113	total: 3.07s	remaining: 576ms
# 842:	learn: 1.1147555	total: 3.07s	remaining: 573ms
# 843:	learn: 1.1146841	total: 3.08s	remaining: 569ms
# 844:	learn: 1.1146130	total: 3.08s	remaining: 565ms
# 845:	learn: 1.1145135	total: 3.08s	remaining: 561ms
# 846:	learn: 1.1144410	total: 3.09s	remaining: 557ms
# 847:	learn: 1.1142394	total: 3.09s	remaining: 554ms
# 848:	learn: 1.1141043	total: 3.09s	remaining: 550ms
# 849:	learn: 1.1140549	total: 3.1s	remaining: 546ms
# 850:	learn: 1.1139205	total: 3.1s	remaining: 542ms
# 851:	learn: 1.1138535	total: 3.1s	remaining: 539ms
# 852:	learn: 1.1138177	total: 3.1s	remaining: 535ms
# 853:	learn: 1.1137464	total: 3.11s	remaining: 531ms
# 854:	learn: 1.1135882	total: 3.11s	remaining: 527ms
# 855:	learn: 1.1133782	total: 3.11s	remaining: 524ms
# 856:	learn: 1.1132691	total: 3.11s	remaining: 520ms
# 857:	learn: 1.1131989	total: 3.12s	remaining: 516ms
# 858:	learn: 1.1130836	total: 3.12s	remaining: 513ms
# 859:	learn: 1.1128456	total: 3.13s	remaining: 509ms
# 860:	learn: 1.1126955	total: 3.13s	remaining: 505ms
# 861:	learn: 1.1125295	total: 3.13s	remaining: 502ms
# 862:	learn: 1.1123502	total: 3.14s	remaining: 499ms
# 863:	learn: 1.1122459	total: 3.14s	remaining: 495ms
# 864:	learn: 1.1121680	total: 3.15s	remaining: 491ms
# 865:	learn: 1.1121129	total: 3.15s	remaining: 488ms
# 866:	learn: 1.1119442	total: 3.16s	remaining: 485ms
# 867:	learn: 1.1118484	total: 3.17s	remaining: 481ms
# 868:	learn: 1.1117486	total: 3.17s	remaining: 478ms
# 869:	learn: 1.1116281	total: 3.17s	remaining: 474ms
# 870:	learn: 1.1115123	total: 3.18s	remaining: 471ms
# 871:	learn: 1.1113715	total: 3.18s	remaining: 467ms
# 872:	learn: 1.1112807	total: 3.18s	remaining: 463ms
# 873:	learn: 1.1111590	total: 3.19s	remaining: 460ms
# 874:	learn: 1.1110533	total: 3.19s	remaining: 456ms
# 875:	learn: 1.1109633	total: 3.19s	remaining: 452ms
# 876:	learn: 1.1108488	total: 3.2s	remaining: 448ms
# 877:	learn: 1.1107353	total: 3.2s	remaining: 445ms
# 878:	learn: 1.1105763	total: 3.2s	remaining: 441ms
# 879:	learn: 1.1104460	total: 3.21s	remaining: 437ms
# 880:	learn: 1.1103513	total: 3.21s	remaining: 433ms
# 881:	learn: 1.1102280	total: 3.21s	remaining: 430ms
# 882:	learn: 1.1101348	total: 3.21s	remaining: 426ms
# 883:	learn: 1.1099878	total: 3.22s	remaining: 422ms
# 884:	learn: 1.1097523	total: 3.22s	remaining: 419ms
# 885:	learn: 1.1096228	total: 3.22s	remaining: 415ms
# 886:	learn: 1.1095155	total: 3.23s	remaining: 411ms
# 887:	learn: 1.1094526	total: 3.23s	remaining: 407ms
# 888:	learn: 1.1093822	total: 3.23s	remaining: 404ms
# 889:	learn: 1.1088751	total: 3.24s	remaining: 400ms
# 890:	learn: 1.1088096	total: 3.24s	remaining: 397ms
# 891:	learn: 1.1085981	total: 3.24s	remaining: 393ms
# 892:	learn: 1.1084960	total: 3.25s	remaining: 389ms
# 893:	learn: 1.1083584	total: 3.25s	remaining: 386ms
# 894:	learn: 1.1083225	total: 3.26s	remaining: 382ms
# 895:	learn: 1.1082372	total: 3.26s	remaining: 379ms
# 896:	learn: 1.1081559	total: 3.27s	remaining: 375ms
# 897:	learn: 1.1079540	total: 3.27s	remaining: 371ms
# 898:	learn: 1.1078334	total: 3.27s	remaining: 368ms
# 899:	learn: 1.1077278	total: 3.27s	remaining: 364ms
# 900:	learn: 1.1076631	total: 3.28s	remaining: 360ms
# 901:	learn: 1.1075767	total: 3.28s	remaining: 356ms
# 902:	learn: 1.1074489	total: 3.28s	remaining: 353ms
# 903:	learn: 1.1073298	total: 3.29s	remaining: 349ms
# 904:	learn: 1.1072477	total: 3.29s	remaining: 345ms
# 905:	learn: 1.1071489	total: 3.29s	remaining: 342ms
# 906:	learn: 1.1070729	total: 3.29s	remaining: 338ms
# 907:	learn: 1.1070337	total: 3.3s	remaining: 334ms
# 908:	learn: 1.1069205	total: 3.3s	remaining: 331ms
# 909:	learn: 1.1067981	total: 3.3s	remaining: 327ms
# 910:	learn: 1.1067361	total: 3.31s	remaining: 323ms
# 911:	learn: 1.1066382	total: 3.31s	remaining: 319ms
# 912:	learn: 1.1065773	total: 3.31s	remaining: 316ms
# 913:	learn: 1.1064550	total: 3.32s	remaining: 312ms
# 914:	learn: 1.1063940	total: 3.32s	remaining: 308ms
# 915:	learn: 1.1062562	total: 3.32s	remaining: 305ms
# 916:	learn: 1.1061796	total: 3.33s	remaining: 301ms
# 917:	learn: 1.1060808	total: 3.33s	remaining: 298ms
# 918:	learn: 1.1059709	total: 3.33s	remaining: 294ms
# 919:	learn: 1.1058146	total: 3.34s	remaining: 290ms
# 920:	learn: 1.1056668	total: 3.34s	remaining: 286ms
# 921:	learn: 1.1055409	total: 3.34s	remaining: 283ms
# 922:	learn: 1.1054579	total: 3.35s	remaining: 279ms
# 923:	learn: 1.1053099	total: 3.35s	remaining: 276ms
# 924:	learn: 1.1051116	total: 3.36s	remaining: 272ms
# 925:	learn: 1.1049756	total: 3.36s	remaining: 268ms
# 926:	learn: 1.1048184	total: 3.36s	remaining: 265ms
# 927:	learn: 1.1047487	total: 3.37s	remaining: 261ms
# ...
# 699:	learn: 1.1333150	total: 2.25s	remaining: 966ms
# 700:	learn: 1.1331912	total: 2.26s	remaining: 963ms
# 701:	learn: 1.1330848	total: 2.26s	remaining: 960ms
# 702:	learn: 1.1329447	total: 2.26s	remaining: 956ms
# 703:	learn: 1.1328324	total: 2.27s	remaining: 953ms
# 704:	learn: 1.1327420	total: 2.27s	remaining: 950ms
# 705:	learn: 1.1326004	total: 2.27s	remaining: 947ms
# 706:	learn: 1.1324451	total: 2.28s	remaining: 944ms
# 707:	learn: 1.1322920	total: 2.28s	remaining: 941ms
# 708:	learn: 1.1322266	total: 2.29s	remaining: 939ms
# 709:	learn: 1.1320934	total: 2.29s	remaining: 936ms
# 710:	learn: 1.1319838	total: 2.29s	remaining: 932ms
# 711:	learn: 1.1318183	total: 2.3s	remaining: 931ms
# 712:	learn: 1.1317030	total: 2.3s	remaining: 928ms
# 713:	learn: 1.1315973	total: 2.31s	remaining: 924ms
# 714:	learn: 1.1314562	total: 2.31s	remaining: 921ms
# 715:	learn: 1.1313353	total: 2.31s	remaining: 918ms
# 716:	learn: 1.1312254	total: 2.32s	remaining: 914ms
# 717:	learn: 1.1311096	total: 2.32s	remaining: 911ms
# 718:	learn: 1.1310172	total: 2.32s	remaining: 907ms
# 719:	learn: 1.1309128	total: 2.32s	remaining: 904ms
# 720:	learn: 1.1307603	total: 2.33s	remaining: 901ms
# 721:	learn: 1.1306576	total: 2.33s	remaining: 897ms
# 722:	learn: 1.1305370	total: 2.33s	remaining: 894ms
# 723:	learn: 1.1304259	total: 2.33s	remaining: 890ms
# 724:	learn: 1.1303242	total: 2.34s	remaining: 887ms
# 725:	learn: 1.1302102	total: 2.34s	remaining: 883ms
# 726:	learn: 1.1300124	total: 2.34s	remaining: 880ms
# 727:	learn: 1.1299431	total: 2.35s	remaining: 876ms
# 728:	learn: 1.1298109	total: 2.35s	remaining: 873ms
# 729:	learn: 1.1297392	total: 2.35s	remaining: 870ms
# 730:	learn: 1.1296033	total: 2.35s	remaining: 866ms
# 731:	learn: 1.1295397	total: 2.36s	remaining: 863ms
# 732:	learn: 1.1293972	total: 2.36s	remaining: 859ms
# 733:	learn: 1.1292869	total: 2.36s	remaining: 856ms
# 734:	learn: 1.1291605	total: 2.37s	remaining: 853ms
# 735:	learn: 1.1290710	total: 2.37s	remaining: 850ms
# 736:	learn: 1.1289615	total: 2.37s	remaining: 846ms
# 737:	learn: 1.1288913	total: 2.37s	remaining: 843ms
# 738:	learn: 1.1286409	total: 2.38s	remaining: 840ms
# 739:	learn: 1.1285253	total: 2.38s	remaining: 836ms
# 740:	learn: 1.1284545	total: 2.38s	remaining: 833ms
# 741:	learn: 1.1283217	total: 2.38s	remaining: 829ms
# 742:	learn: 1.1282095	total: 2.39s	remaining: 826ms
# 743:	learn: 1.1280708	total: 2.39s	remaining: 823ms
# 744:	learn: 1.1279864	total: 2.39s	remaining: 819ms
# 745:	learn: 1.1278767	total: 2.4s	remaining: 816ms
# 746:	learn: 1.1277487	total: 2.4s	remaining: 813ms
# 747:	learn: 1.1277065	total: 2.4s	remaining: 809ms
# 748:	learn: 1.1276187	total: 2.4s	remaining: 806ms
# 749:	learn: 1.1274852	total: 2.41s	remaining: 803ms
# 750:	learn: 1.1272713	total: 2.41s	remaining: 800ms
# 751:	learn: 1.1272103	total: 2.41s	remaining: 796ms
# 752:	learn: 1.1271449	total: 2.42s	remaining: 793ms
# 753:	learn: 1.1270927	total: 2.42s	remaining: 789ms
# 754:	learn: 1.1269639	total: 2.42s	remaining: 786ms
# 755:	learn: 1.1268854	total: 2.43s	remaining: 783ms
# 756:	learn: 1.1267841	total: 2.43s	remaining: 780ms
# 757:	learn: 1.1266339	total: 2.44s	remaining: 778ms
# 758:	learn: 1.1264825	total: 2.44s	remaining: 774ms
# 759:	learn: 1.1263746	total: 2.44s	remaining: 771ms
# 760:	learn: 1.1262355	total: 2.44s	remaining: 768ms
# 761:	learn: 1.1260381	total: 2.45s	remaining: 764ms
# 762:	learn: 1.1259007	total: 2.45s	remaining: 761ms
# 763:	learn: 1.1257705	total: 2.45s	remaining: 757ms
# 764:	learn: 1.1256770	total: 2.46s	remaining: 754ms
# 765:	learn: 1.1255953	total: 2.46s	remaining: 751ms
# 766:	learn: 1.1255057	total: 2.46s	remaining: 749ms
# 767:	learn: 1.1253556	total: 2.47s	remaining: 746ms
# 768:	learn: 1.1252092	total: 2.47s	remaining: 743ms
# 769:	learn: 1.1249562	total: 2.48s	remaining: 740ms
# 770:	learn: 1.1248719	total: 2.48s	remaining: 737ms
# 771:	learn: 1.1247751	total: 2.48s	remaining: 733ms
# 772:	learn: 1.1246618	total: 2.48s	remaining: 730ms
# 773:	learn: 1.1244911	total: 2.49s	remaining: 726ms
# 774:	learn: 1.1243139	total: 2.49s	remaining: 723ms
# 775:	learn: 1.1242441	total: 2.49s	remaining: 720ms
# 776:	learn: 1.1241575	total: 2.5s	remaining: 717ms
# 777:	learn: 1.1240229	total: 2.5s	remaining: 713ms
# 778:	learn: 1.1239031	total: 2.5s	remaining: 710ms
# 779:	learn: 1.1238169	total: 2.51s	remaining: 707ms
# 780:	learn: 1.1237335	total: 2.51s	remaining: 704ms
# 781:	learn: 1.1236495	total: 2.51s	remaining: 700ms
# 782:	learn: 1.1235580	total: 2.52s	remaining: 697ms
# 783:	learn: 1.1234683	total: 2.52s	remaining: 694ms
# 784:	learn: 1.1234087	total: 2.52s	remaining: 691ms
# 785:	learn: 1.1233626	total: 2.53s	remaining: 688ms
# 786:	learn: 1.1232532	total: 2.53s	remaining: 685ms
# 787:	learn: 1.1231762	total: 2.53s	remaining: 681ms
# 788:	learn: 1.1230549	total: 2.54s	remaining: 678ms
# 789:	learn: 1.1229181	total: 2.54s	remaining: 675ms
# 790:	learn: 1.1228084	total: 2.54s	remaining: 672ms
# 791:	learn: 1.1226879	total: 2.54s	remaining: 669ms
# 792:	learn: 1.1224973	total: 2.55s	remaining: 665ms
# 793:	learn: 1.1224737	total: 2.55s	remaining: 662ms
# 794:	learn: 1.1223619	total: 2.56s	remaining: 659ms
# 795:	learn: 1.1222656	total: 2.56s	remaining: 656ms
# 796:	learn: 1.1221584	total: 2.56s	remaining: 653ms
# 797:	learn: 1.1221009	total: 2.56s	remaining: 649ms
# 798:	learn: 1.1220082	total: 2.57s	remaining: 646ms
# 799:	learn: 1.1218229	total: 2.57s	remaining: 643ms
# 800:	learn: 1.1216660	total: 2.57s	remaining: 639ms
# 801:	learn: 1.1215266	total: 2.58s	remaining: 636ms
# 802:	learn: 1.1209409	total: 2.58s	remaining: 632ms
# 803:	learn: 1.1208262	total: 2.58s	remaining: 629ms
# 804:	learn: 1.1207521	total: 2.58s	remaining: 626ms
# 805:	learn: 1.1205364	total: 2.59s	remaining: 623ms
# 806:	learn: 1.1204270	total: 2.59s	remaining: 619ms
# 807:	learn: 1.1203100	total: 2.59s	remaining: 616ms
# 808:	learn: 1.1201678	total: 2.6s	remaining: 613ms
# 809:	learn: 1.1200694	total: 2.6s	remaining: 610ms
# 810:	learn: 1.1200296	total: 2.6s	remaining: 607ms
# 811:	learn: 1.1199238	total: 2.61s	remaining: 604ms
# 812:	learn: 1.1197491	total: 2.61s	remaining: 601ms
# 813:	learn: 1.1196077	total: 2.61s	remaining: 597ms
# 814:	learn: 1.1195428	total: 2.62s	remaining: 594ms
# 815:	learn: 1.1194015	total: 2.62s	remaining: 591ms
# 816:	learn: 1.1192605	total: 2.62s	remaining: 588ms
# 817:	learn: 1.1190633	total: 2.63s	remaining: 584ms
# 818:	learn: 1.1189321	total: 2.63s	remaining: 581ms
# 819:	learn: 1.1188990	total: 2.63s	remaining: 578ms
# 820:	learn: 1.1187617	total: 2.63s	remaining: 574ms
# 821:	learn: 1.1186734	total: 2.64s	remaining: 571ms
# 822:	learn: 1.1185320	total: 2.64s	remaining: 568ms
# 823:	learn: 1.1183708	total: 2.64s	remaining: 564ms
# 824:	learn: 1.1182460	total: 2.65s	remaining: 561ms
# 825:	learn: 1.1181075	total: 2.65s	remaining: 558ms
# 826:	learn: 1.1180324	total: 2.65s	remaining: 555ms
# 827:	learn: 1.1179475	total: 2.66s	remaining: 552ms
# 828:	learn: 1.1178641	total: 2.66s	remaining: 549ms
# 829:	learn: 1.1177364	total: 2.66s	remaining: 546ms
# 830:	learn: 1.1175967	total: 2.67s	remaining: 542ms
# 831:	learn: 1.1175090	total: 2.67s	remaining: 539ms
# 832:	learn: 1.1173406	total: 2.67s	remaining: 536ms
# 833:	learn: 1.1172486	total: 2.68s	remaining: 533ms
# 834:	learn: 1.1171408	total: 2.68s	remaining: 530ms
# 835:	learn: 1.1171070	total: 2.68s	remaining: 527ms
# 836:	learn: 1.1169815	total: 2.69s	remaining: 523ms
# 837:	learn: 1.1167792	total: 2.69s	remaining: 520ms
# 838:	learn: 1.1166907	total: 2.69s	remaining: 517ms
# 839:	learn: 1.1165148	total: 2.69s	remaining: 513ms
# 840:	learn: 1.1163954	total: 2.7s	remaining: 510ms
# 841:	learn: 1.1162994	total: 2.7s	remaining: 507ms
# 842:	learn: 1.1162204	total: 2.71s	remaining: 504ms
# 843:	learn: 1.1160092	total: 2.71s	remaining: 501ms
# 844:	learn: 1.1159002	total: 2.71s	remaining: 498ms
# 845:	learn: 1.1158119	total: 2.72s	remaining: 494ms
# 846:	learn: 1.1157091	total: 2.72s	remaining: 492ms
# 847:	learn: 1.1155650	total: 2.72s	remaining: 488ms
# 848:	learn: 1.1154348	total: 2.73s	remaining: 485ms
# 849:	learn: 1.1152882	total: 2.73s	remaining: 482ms
# 850:	learn: 1.1151767	total: 2.73s	remaining: 479ms
# 851:	learn: 1.1149693	total: 2.74s	remaining: 476ms
# 852:	learn: 1.1148654	total: 2.74s	remaining: 473ms
# 853:	learn: 1.1147853	total: 2.75s	remaining: 470ms
# 854:	learn: 1.1146791	total: 2.75s	remaining: 467ms
# 855:	learn: 1.1146254	total: 2.75s	remaining: 463ms
# 856:	learn: 1.1145491	total: 2.76s	remaining: 460ms
# 857:	learn: 1.1144837	total: 2.76s	remaining: 457ms
# 858:	learn: 1.1143655	total: 2.76s	remaining: 453ms
# 859:	learn: 1.1142953	total: 2.77s	remaining: 450ms
# 860:	learn: 1.1141897	total: 2.77s	remaining: 447ms
# 861:	learn: 1.1140149	total: 2.77s	remaining: 444ms
# 862:	learn: 1.1139400	total: 2.77s	remaining: 440ms
# 863:	learn: 1.1138333	total: 2.78s	remaining: 437ms
# 864:	learn: 1.1137693	total: 2.78s	remaining: 434ms
# 865:	learn: 1.1136578	total: 2.78s	remaining: 431ms
# 866:	learn: 1.1133999	total: 2.79s	remaining: 428ms
# 867:	learn: 1.1132779	total: 2.79s	remaining: 424ms
# 868:	learn: 1.1131638	total: 2.79s	remaining: 421ms
# 869:	learn: 1.1130664	total: 2.8s	remaining: 418ms
# 870:	learn: 1.1129462	total: 2.8s	remaining: 415ms
# 871:	learn: 1.1128413	total: 2.8s	remaining: 412ms
# 872:	learn: 1.1127242	total: 2.81s	remaining: 408ms
# 873:	learn: 1.1125373	total: 2.81s	remaining: 405ms
# 874:	learn: 1.1123863	total: 2.81s	remaining: 402ms
# 875:	learn: 1.1123344	total: 2.82s	remaining: 399ms
# 876:	learn: 1.1121854	total: 2.82s	remaining: 395ms
# 877:	learn: 1.1120494	total: 2.82s	remaining: 392ms
# 878:	learn: 1.1118789	total: 2.82s	remaining: 389ms
# 879:	learn: 1.1117316	total: 2.83s	remaining: 385ms
# 880:	learn: 1.1116737	total: 2.83s	remaining: 382ms
# 881:	learn: 1.1115875	total: 2.83s	remaining: 379ms
# 882:	learn: 1.1114648	total: 2.83s	remaining: 375ms
# 883:	learn: 1.1113734	total: 2.83s	remaining: 372ms
# 884:	learn: 1.1113425	total: 2.84s	remaining: 369ms
# 885:	learn: 1.1112944	total: 2.84s	remaining: 366ms
# 886:	learn: 1.1111792	total: 2.85s	remaining: 362ms
# 887:	learn: 1.1110473	total: 2.85s	remaining: 360ms
# 888:	learn: 1.1109484	total: 2.85s	remaining: 357ms
# 889:	learn: 1.1108696	total: 2.86s	remaining: 353ms
# 890:	learn: 1.1107510	total: 2.87s	remaining: 351ms
# 891:	learn: 1.1106995	total: 2.87s	remaining: 348ms
# 892:	learn: 1.1106471	total: 2.87s	remaining: 344ms
# 893:	learn: 1.1105489	total: 2.88s	remaining: 341ms
# 894:	learn: 1.1103896	total: 2.88s	remaining: 338ms
# 895:	learn: 1.1102575	total: 2.89s	remaining: 335ms
# 896:	learn: 1.1101765	total: 2.89s	remaining: 332ms
# 897:	learn: 1.1100917	total: 2.89s	remaining: 328ms
# 898:	learn: 1.1099700	total: 2.89s	remaining: 325ms
# 899:	learn: 1.1099058	total: 2.9s	remaining: 322ms
# 900:	learn: 1.1098191	total: 2.9s	remaining: 319ms
# 901:	learn: 1.1096005	total: 2.91s	remaining: 316ms
# 902:	learn: 1.1094857	total: 2.91s	remaining: 313ms
# 903:	learn: 1.1093352	total: 2.92s	remaining: 310ms
# 904:	learn: 1.1092562	total: 2.92s	remaining: 307ms
# 905:	learn: 1.1090749	total: 2.93s	remaining: 304ms
# 906:	learn: 1.1090136	total: 2.93s	remaining: 301ms
# 907:	learn: 1.1088333	total: 2.94s	remaining: 298ms
# 908:	learn: 1.1087859	total: 2.94s	remaining: 295ms
# 909:	learn: 1.1086522	total: 2.95s	remaining: 291ms
# 910:	learn: 1.1085811	total: 2.95s	remaining: 288ms
# 911:	learn: 1.1082429	total: 2.95s	remaining: 285ms
# 912:	learn: 1.1081703	total: 2.96s	remaining: 282ms
# 913:	learn: 1.1080052	total: 2.96s	remaining: 278ms
# 914:	learn: 1.1078713	total: 2.96s	remaining: 275ms
# 915:	learn: 1.1077464	total: 2.96s	remaining: 272ms
# 916:	learn: 1.1076145	total: 2.97s	remaining: 269ms
# 917:	learn: 1.1075581	total: 2.97s	remaining: 265ms
# 918:	learn: 1.1074426	total: 2.98s	remaining: 262ms
# 919:	learn: 1.1073257	total: 2.98s	remaining: 259ms
# 920:	learn: 1.1072472	total: 2.98s	remaining: 256ms
# 921:	learn: 1.1071896	total: 2.99s	remaining: 253ms
# 922:	learn: 1.1070848	total: 2.99s	remaining: 250ms
# 923:	learn: 1.1069858	total: 3s	remaining: 246ms
# 924:	learn: 1.1068853	total: 3s	remaining: 243ms
# 925:	learn: 1.1067746	total: 3s	remaining: 240ms
# 926:	learn: 1.1066433	total: 3.01s	remaining: 237ms
# 927:	learn: 1.1063960	total: 3.01s	remaining: 234ms
# 928:	learn: 1.1062057	total: 3.01s	remaining: 230ms
# 929:	learn: 1.1060536	total: 3.02s	remaining: 227ms
# 930:	learn: 1.1060275	total: 3.02s	remaining: 224ms
# 931:	learn: 1.1059982	total: 3.02s	remaining: 220ms
# 932:	learn: 1.1058323	total: 3.02s	remaining: 217ms
# 933:	learn: 1.1056333	total: 3.03s	remaining: 214ms
# 934:	learn: 1.1055641	total: 3.03s	remaining: 211ms
# 935:	learn: 1.1054360	total: 3.03s	remaining: 207ms
# 936:	learn: 1.1053456	total: 3.03s	remaining: 204ms
# 937:	learn: 1.1051333	total: 3.04s	remaining: 201ms
# 938:	learn: 1.1050430	total: 3.04s	remaining: 197ms
# 939:	learn: 1.1049654	total: 3.04s	remaining: 194ms
# 940:	learn: 1.1049108	total: 3.05s	remaining: 191ms
# 941:	learn: 1.1047655	total: 3.05s	remaining: 188ms
# 942:	learn: 1.1046442	total: 3.05s	remaining: 184ms
# 943:	learn: 1.1045701	total: 3.05s	remaining: 181ms
# 944:	learn: 1.1044338	total: 3.06s	remaining: 178ms
# 945:	learn: 1.1043377	total: 3.06s	remaining: 175ms
# 946:	learn: 1.1038296	total: 3.06s	remaining: 171ms
# 947:	learn: 1.1037142	total: 3.07s	remaining: 168ms
# 948:	learn: 1.1036093	total: 3.07s	remaining: 165ms
# 949:	learn: 1.1035090	total: 3.08s	remaining: 162ms
# 950:	learn: 1.1034272	total: 3.08s	remaining: 159ms
# 951:	learn: 1.1033486	total: 3.08s	remaining: 155ms
# 952:	learn: 1.1032680	total: 3.08s	remaining: 152ms
# 953:	learn: 1.1031562	total: 3.09s	remaining: 149ms
# 954:	learn: 1.1030131	total: 3.09s	remaining: 146ms
# 955:	learn: 1.1029714	total: 3.09s	remaining: 142ms
# 956:	learn: 1.1028988	total: 3.1s	remaining: 139ms
# 957:	learn: 1.1027763	total: 3.1s	remaining: 136ms
# 958:	learn: 1.1027298	total: 3.1s	remaining: 133ms
# 959:	learn: 1.1026900	total: 3.1s	remaining: 129ms
# 960:	learn: 1.1026605	total: 3.11s	remaining: 126ms
# 961:	learn: 1.1025882	total: 3.11s	remaining: 123ms
# 962:	learn: 1.1025065	total: 3.11s	remaining: 120ms
# 963:	learn: 1.1024027	total: 3.12s	remaining: 116ms
# 964:	learn: 1.1022581	total: 3.12s	remaining: 113ms
# 965:	learn: 1.1021152	total: 3.12s	remaining: 110ms
# 966:	learn: 1.1019800	total: 3.13s	remaining: 107ms
# 967:	learn: 1.1018623	total: 3.13s	remaining: 104ms
# 968:	learn: 1.1017299	total: 3.13s	remaining: 100ms
# 969:	learn: 1.1016895	total: 3.14s	remaining: 97ms
# 970:	learn: 1.1015872	total: 3.14s	remaining: 93.7ms
# 971:	learn: 1.1015334	total: 3.14s	remaining: 90.5ms
# 972:	learn: 1.1014679	total: 3.14s	remaining: 87.2ms
# 973:	learn: 1.1013294	total: 3.15s	remaining: 84ms
# 974:	learn: 1.1011726	total: 3.15s	remaining: 80.7ms
# 975:	learn: 1.1011058	total: 3.15s	remaining: 77.5ms
# 976:	learn: 1.1010298	total: 3.15s	remaining: 74.3ms
# 977:	learn: 1.1009174	total: 3.16s	remaining: 71ms
# 978:	learn: 1.1007585	total: 3.16s	remaining: 67.8ms
# 979:	learn: 1.1006917	total: 3.16s	remaining: 64.6ms
# 980:	learn: 1.1006105	total: 3.17s	remaining: 61.4ms
# 981:	learn: 1.1004361	total: 3.17s	remaining: 58.1ms
# 982:	learn: 1.1003463	total: 3.17s	remaining: 54.9ms
# 983:	learn: 1.1002436	total: 3.18s	remaining: 51.7ms
# 984:	learn: 1.1001350	total: 3.18s	remaining: 48.4ms
# 985:	learn: 1.1000659	total: 3.18s	remaining: 45.2ms
# 986:	learn: 1.0999530	total: 3.19s	remaining: 42ms
# 987:	learn: 1.0998460	total: 3.19s	remaining: 38.7ms
# 988:	learn: 1.0998239	total: 3.19s	remaining: 35.5ms
# 989:	learn: 1.0997497	total: 3.19s	remaining: 32.3ms
# 990:	learn: 1.0996589	total: 3.2s	remaining: 29ms
# 991:	learn: 1.0994700	total: 3.2s	remaining: 25.8ms
# 992:	learn: 1.0989775	total: 3.2s	remaining: 22.6ms
# 993:	learn: 1.0989272	total: 3.21s	remaining: 19.3ms
# 994:	learn: 1.0988354	total: 3.21s	remaining: 16.1ms
# 995:	learn: 1.0986958	total: 3.21s	remaining: 12.9ms
# 996:	learn: 1.0985767	total: 3.21s	remaining: 9.67ms
# 997:	learn: 1.0984250	total: 3.21s	remaining: 6.44ms
# 998:	learn: 1.0983055	total: 3.22s	remaining: 3.22ms
# 999:	learn: 1.0979145	total: 3.22s	remaining: 0us
# {'fit_time': array([4.05880713, 4.10682511, 3.48435926, 3.80279207, 3.59219313]),
#  'score_time': array([0.04768586, 0.04714489, 0.0322268 , 0.0532279 , 0.03454185]),
#  'test_score': array([0.40955712, 0.36821319, 0.34564944, 0.40602067, 0.3963444 ]),
#  'train_score': array([0.54014416, 0.54314789, 0.53016177, 0.54101349, 0.54213296])}

# %% [markdown]
# <!-- END QUESTION -->
#
# <br><br>

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ## (Challenging) 9. Feature selection <a name="9"></a>
# <hr>
# rubric={points:2}
#
# **Your tasks:**
#
# Make some attempts to select relevant features. You may try `RFECV` or forward selection for this. Do the results improve with feature selection? Summarize your results. If you see improvements in the results, keep feature selection in your pipeline. If not, you may abandon it in the next exercises.

# %% [markdown]
# <div class="alert alert-warning">
#
# Solution_9
#
# </div>
#
# _Points:_ 2

# %% [markdown]
# _Type your answer here, replacing this text._

# %%
...

# %%
...

# %%
...

# %% [markdown]
# <!-- END QUESTION -->
#
# <br><br>

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ## 10. Hyperparameter optimization <a name="10"></a>
# <hr>
# rubric={points:10}
#
# **Your tasks:**
#
# Make some attempts to optimize hyperparameters for the models you've tried and summarize your results. In at least one case you should be optimizing multiple hyperparameters for a single model. You may use `sklearn`'s methods for hyperparameter optimization or fancier Bayesian optimization methods.
#   - [GridSearchCV](http://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html)
#   - [RandomizedSearchCV](http://scikit-learn.org/stable/modules/generated/sklearn.model_selection.RandomizedSearchCV.html)
#   - [scikit-optimize](https://github.com/scikit-optimize/scikit-optimize)

# %% [markdown]
# <div class="alert alert-warning">
#
# Solution_10
#
# </div>
#
# _Points:_ 10

# %% [markdown]
# _Type your answer here, replacing this text._

# %%
...

# %%
...

# %%
...

# %%
...

# %%
...

# %%
...

# %%
...

# %%
...

# %% [markdown]
# <!-- END QUESTION -->
#
# <br><br>

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ## 11. Interpretation and feature importances <a name="1"></a>
# <hr>
# rubric={points:10}
#
# **Your tasks:**
#
# 1. Use the methods we saw in class (e.g., `eli5`, `shap`) (or any other methods of your choice) to examine the most important features of one of the non-linear models.
# 2. Summarize your observations.

# %% [markdown]
# <div class="alert alert-warning">
#
# Solution_11
#
# </div>
#
# _Points:_ 10

# %% [markdown]
# _Type your answer here, replacing this text._

# %%
...

# %%
...

# %%
...

# %%
...

# %%
...

# %%
...

# %%
...

# %%
...

# %%
...

# %%
...

# %%
...

# %% [markdown]
# <!-- END QUESTION -->
#
# <br><br>

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ## 12. Results on the test set <a name="12"></a>
# <hr>
#
# rubric={points:10}
#
# **Your tasks:**
#
# 1. Try your best performing model on the test data and report test scores.
# 2. Do the test scores agree with the validation scores from before? To what extent do you trust your results? Do you think you've had issues with optimization bias?
# 3. Take one or two test predictions and explain these individual predictions (e.g., with SHAP force plots).

# %% [markdown]
# <div class="alert alert-warning">
#
# Solution_12
#
# </div>
#
# _Points:_ 10

# %% [markdown]
# _Type your answer here, replacing this text._

# %%
...

# %%
...

# %%
...

# %%
...

# %%
...

# %%
...

# %%
...

# %%
...

# %%
...

# %% [markdown]
# <!-- END QUESTION -->
#
# <br><br>

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ## 13. Summary of results <a name="13"></a>
# <hr>
# rubric={points:12}
#
# Imagine that you want to present the summary of these results to your boss and co-workers.
#
# **Your tasks:**
#
# 1. Create a table summarizing important results.
# 2. Write concluding remarks.
# 3. Discuss other ideas that you did not try but could potentially improve the performance/interpretability .
# 3. Report your final test score along with the metric you used at the top of this notebook in the [Submission instructions section](#si).

# %% [markdown]
# <div class="alert alert-warning">
#
# Solution_13
#
# </div>
#
# _Points:_ 12

# %% [markdown]
# _Type your answer here, replacing this text._

# %%
...

# %%
...

# %% [markdown]
# <!-- END QUESTION -->
#
# <br><br>

# %% [markdown]
# <br><br>

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ## (Challenging) 14. Your takeaway <a name="15"></a>
# <hr>
# rubric={points:2}
#
# **Your tasks:**
#
# What is your biggest takeaway from the supervised machine learning material we have learned so far? Please write thoughtful answers.

# %% [markdown]
# <div class="alert alert-warning">
#
# Solution_14
#
# </div>
#
# _Points:_ 2

# %% [markdown]
# <!-- END QUESTION -->
#
# <br><br>

# %% [markdown]
# **Before submitting your assignment, please make sure you have followed all the instructions in the Submission instructions section at the top.**

# %% [markdown]
# This was a tricky one but you did it! Have a great weekend!

# %% [markdown]
# ![](img/eva-well-done.png)
